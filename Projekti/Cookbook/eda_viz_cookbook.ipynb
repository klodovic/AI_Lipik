# %%
# 📘 EDA & Vizualizacijski Cookbook
from toolbox import *

## 🔹 1. Učitavanje podataka
df = quick_eda('podaci.csv')

## 🔹 2. Grupiranje i agregacija
df_groupby(df, ['Spol'], 'mean')
agg_column_multi(df, 'Stambeni_Status', 'Odobreni_Iznos_EUR', ['count', 'mean', 'min', 'max'])

## 🔹 3. Vizualizacije
# Histogram
plot_histogram(df, 'Starost_Klijenta')

# Boxplot
plot_boxplot(df, 'Trenutni_Dug_EUR')

# Pie chart
plot_pie(df, 'Stambeni_Status', 'Odobreni_Iznos_EUR')

# Korelacijska matrica
plot_correlation_matrix(df)

# Countplot za klasifikacijsku varijablu
plot_count(df, 'Obrazovanje')

# Barplot
plot_bar(df, 'Obrazovanje', 'Odobreni_Iznos_EUR')

# Scatterplot
plot_scatter(df, 'Starost_Klijenta', 'Odobreni_Iznos_EUR')

# Pairplot za odabrane numeričke kolone
plot_pairplot(df[['Starost_Klijenta', 'Odobreni_Iznos_EUR', 'Trenutni_Dug_EUR']])

## 🔹 4. IQR obrada outliera
df['Trenutni_Dug_EUR_Capped'] = iqr_method(df['Trenutni_Dug_EUR'])

## 🔹 5. Procjena radnog staža
estimated_work_experience_calculations(df)
