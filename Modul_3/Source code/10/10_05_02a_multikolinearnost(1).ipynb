# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
df = pd.DataFrame({
    'grad': ['Zagreb', 'Split', 'Rijeka'],
    'cijena': [100, 120, 90]})
X = df[['grad']]
y = df['cijena']
ohe = OneHotEncoder(drop=None, sparse_output=False)
#ohe = OneHotEncoder(drop='first', sparse_output=False)
Z = ohe.fit_transform(df[['grad']])
dummy_cols = list(ohe.get_feature_names_out(['grad']))  # ['grad_Zagreb','grad_Split','grad_Rijeka']
print(Z)
lr = LinearRegression()
lr.fit(Z, y)
print("Koeficijenti (bez drop):", lr.coef_)
print("Intercept (bez drop):", lr.intercept_)
# Out:
# [[0. 0. 1.]
#  [0. 1. 0.]
#  [1. 0. 0.]]
# ['grad_Rijeka', 'grad_Split', 'grad_Zagreb']
# Koeficijenti (bez drop): [-13.33333333  16.66666667  -3.33333333]
# Intercept (bez drop): 103.33333333333333
