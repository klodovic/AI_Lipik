# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

df = pd.DataFrame({
    'grad': ['Zagreb', 'Split', 'Rijeka'],
    'cijena': [100, 120, 90]})

X = df[['grad']]
y = df['cijena']

ohe = OneHotEncoder(drop='first', sparse_output=False) # Set sparse_output to False
Z = ohe.fit_transform(df[['grad']])
dummy_cols = list(ohe.get_feature_names_out(['grad']))  # ['grad_Zagreb','grad_Split','grad_Rijeka']
print(Z)

lr = LinearRegression()
lr.fit(Z, y)
print("Koeficijenti (s drop):", lr.coef_)
print("Intercept (s drop):", lr.intercept_)
# Out:
# [[0. 1.]
#  [1. 0.]
#  [0. 0.]]
# Koeficijenti (s drop): [30. 10.]
# Intercept (s drop): 90.0
