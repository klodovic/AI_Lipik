# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats

# %%
uspjeh_studenata = pd.read_csv("st_uspjeh.csv")
streaming = pd.read_csv("streaming.csv")

# %%
def apply_iqr_capping(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Primjena cappinga
    # Sve vrijednosti manje od donje granice postaju donja granica
    # Sve vrijednosti veće od gornje granice postaju gornja granica
    # round() zakružujemo sve vrijednosti
    capped_series = series.clip(lower=lower_bound, upper=upper_bound)
    return capped_series

# %%
uspjeh_studenata
# Out:
#     Unnamed: 0  StudentID    Drzava        Smjer  Godina_Studija  \
# 0            0          1  Hrvatska  Informatika               1
# 1            1          2  Hrvatska        Pravo               1
# 2            2          3  Hrvatska  Informatika               5
# 3            3          4  Hrvatska    Ekonomija               5
# 4            4          5  Hrvatska  Informatika               4
# ..         ...        ...       ...          ...             ...
# 95          95         96  Hrvatska        Pravo               5
# 96          96         97  Hrvatska     Medicina               1
# 97          97         98  Hrvatska        Pravo               5
# 98          98         99  Hrvatska    Ekonomija               4
# 99          99        100  Hrvatska    Ekonomija               2
#
#     Prosjek_Ocjena  Broj_Polozenih_Ispita      Status
# 0             3.83                    8.0  Izvanredan
# 1             4.31                    3.0  Izvanredan
# 2             2.16                    3.0     Redovan
# 3             3.37                    5.0     Redovan
# 4             4.51                    2.0   Apsolvent
# ..             ...                    ...         ...
# 95             NaN                    7.0     Redovan
# 96            2.28                    3.0     Redovan
# 97            4.20                   10.0   Zamrznuto
# 98            2.88                    5.0     Redovan
# 99            3.51                    4.0     Redovan
#
# [100 rows x 8 columns]

# %%
uspjeh_studenata.isna().sum()
# Out:
# Unnamed: 0               0
# StudentID                0
# Drzava                   0
# Smjer                    7
# Godina_Studija           0
# Prosjek_Ocjena           5
# Broj_Polozenih_Ispita    6
# Status                   4
# dtype: int64

# %%
uspjeh_studenata.describe()
# Out:
#        Unnamed: 0   StudentID  Godina_Studija  Prosjek_Ocjena  \
# count  100.000000  100.000000      100.000000       95.000000
# mean    49.500000   50.500000        2.940000        3.392526
# std     29.011492   29.011492        1.983874        0.749001
# min      0.000000    1.000000        1.000000        1.360000
# 25%     24.750000   25.750000        1.000000        2.910000
# 50%     49.500000   50.500000        3.000000        3.370000
# 75%     74.250000   75.250000        4.000000        3.965000
# max     99.000000  100.000000       12.000000        5.000000
#
#        Broj_Polozenih_Ispita
# count              94.000000
# mean                5.723404
# std                 3.105334
# min                 1.000000
# 25%                 3.000000
# 50%                 5.000000
# 75%                 7.000000
# max                14.000000

# %%
uspjeh_studenata.drop(columns=["Unnamed: 0", "Drzava"], inplace=True)

# %%
uspjeh_studenata
# Out:
#     StudentID        Smjer  Godina_Studija  Prosjek_Ocjena  \
# 0           1  Informatika               1            3.83
# 1           2        Pravo               1            4.31
# 2           3  Informatika               5            2.16
# 3           4    Ekonomija               5            3.37
# 4           5  Informatika               4            4.51
# ..        ...          ...             ...             ...
# 95         96        Pravo               5             NaN
# 96         97     Medicina               1            2.28
# 97         98        Pravo               5            4.20
# 98         99    Ekonomija               4            2.88
# 99        100    Ekonomija               2            3.51
#
#     Broj_Polozenih_Ispita      Status
# 0                     8.0  Izvanredan
# 1                     3.0  Izvanredan
# 2                     3.0     Redovan
# 3                     5.0     Redovan
# 4                     2.0   Apsolvent
# ..                    ...         ...
# 95                    7.0     Redovan
# 96                    3.0     Redovan
# 97                   10.0   Zamrznuto
# 98                    5.0     Redovan
# 99                    4.0     Redovan
#
# [100 rows x 6 columns]

# %%
isna_values = uspjeh_studenata[uspjeh_studenata.isna().any(axis=1)]

# %%
isna_values
# Out:
#     StudentID        Smjer  Godina_Studija  Prosjek_Ocjena  \
# 7           8    Ekonomija               5            1.76
# 8           9  Informatika               2             NaN
# 16         17          NaN               3            3.51
# 20         21          NaN               3            3.65
# 22         23          NaN               1            3.77
# 30         31  Informatika               2            3.58
# 33         34          NaN               1            3.65
# 36         37          NaN               1            3.96
# 46         47    Ekonomija               3            2.99
# 54         55        Pravo               4             NaN
# 57         58  Strojarstvo               2            3.60
# 69         70    Ekonomija               1            3.11
# 71         72  Informatika               5             NaN
# 76         77        Pravo               5             NaN
# 78         79    Ekonomija               2            2.95
# 79         80          NaN               5            4.60
# 81         82  Informatika               2            4.18
# 88         89  Informatika               3            2.76
# 94         95          NaN               1            3.08
# 95         96        Pravo               5             NaN
#
#     Broj_Polozenih_Ispita      Status
# 7                     8.0         NaN
# 8                     2.0  Izvanredan
# 16                    NaN     Redovan
# 20                    1.0  Izvanredan
# 22                    1.0  Izvanredan
# 30                    3.0         NaN
# 33                    4.0     Redovan
# 36                    4.0   Apsolvent
# 46                    NaN         NaN
# 54                    3.0     Redovan
# 57                    4.0         NaN
# 69                    NaN     Redovan
# 71                    3.0  Izvanredan
# 76                    5.0  Izvanredan
# 78                    NaN     Redovan
# 79                    5.0     Redovan
# 81                    NaN   Apsolvent
# 88                    NaN     Redovan
# 94                    3.0     Redovan
# 95                    7.0     Redovan

# %%
uspjeh_studenata2 = uspjeh_studenata.copy()

# %%
### Smjer

# %%
uspjeh_studenata2["Smjer"].mode()
# Out:
# 0    Informatika
# Name: Smjer, dtype: object

# %%
uspjeh_studenata2["Smjer"].fillna(value = "Informatika", inplace = True)
# Out:
# C:\Users\Syntari\AppData\Local\Temp\ipykernel_25136\3134156741.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   uspjeh_studenata2["Smjer"].fillna(value = "Informatika", inplace = True)

# %%
uspjeh_studenata2.isna().sum()
# Out:
# StudentID                0
# Smjer                    0
# Godina_Studija           0
# Prosjek_Ocjena           5
# Broj_Polozenih_Ispita    6
# Status                   4
# dtype: int64

# %%
#### Status

# %%
uspjeh_studenata2["Status"].mode()
# Out:
# 0    Redovan
# Name: Status, dtype: object

# %%
uspjeh_studenata2["Status"].fillna(value = "Redovan", inplace = True)
# Out:
# C:\Users\Syntari\AppData\Local\Temp\ipykernel_25136\1444882256.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   uspjeh_studenata2["Status"].fillna(value = "Redovan", inplace = True)

# %%
nan_values = uspjeh_studenata2[uspjeh_studenata.isna().any(axis=1)]
nan_values
# Out:
#     StudentID        Smjer  Godina_Studija  Prosjek_Ocjena  \
# 7           8    Ekonomija               5            1.76
# 8           9  Informatika               2             NaN
# 16         17  Informatika               3            3.51
# 20         21  Informatika               3            3.65
# 22         23  Informatika               1            3.77
# 30         31  Informatika               2            3.58
# 33         34  Informatika               1            3.65
# 36         37  Informatika               1            3.96
# 46         47    Ekonomija               3            2.99
# 54         55        Pravo               4             NaN
# 57         58  Strojarstvo               2            3.60
# 69         70    Ekonomija               1            3.11
# 71         72  Informatika               5             NaN
# 76         77        Pravo               5             NaN
# 78         79    Ekonomija               2            2.95
# 79         80  Informatika               5            4.60
# 81         82  Informatika               2            4.18
# 88         89  Informatika               3            2.76
# 94         95  Informatika               1            3.08
# 95         96        Pravo               5             NaN
#
#     Broj_Polozenih_Ispita      Status
# 7                     8.0     Redovan
# 8                     2.0  Izvanredan
# 16                    NaN     Redovan
# 20                    1.0  Izvanredan
# 22                    1.0  Izvanredan
# 30                    3.0     Redovan
# 33                    4.0     Redovan
# 36                    4.0   Apsolvent
# 46                    NaN     Redovan
# 54                    3.0     Redovan
# 57                    4.0     Redovan
# 69                    NaN     Redovan
# 71                    3.0  Izvanredan
# 76                    5.0  Izvanredan
# 78                    NaN     Redovan
# 79                    5.0     Redovan
# 81                    NaN   Apsolvent
# 88                    NaN     Redovan
# 94                    3.0     Redovan
# 95                    7.0     Redovan

# %%
#### Godina studija

# %%
uspjeh_studenata2.sort_values (by = ["Godina_Studija"])
# Out:
#     StudentID        Smjer  Godina_Studija  Prosjek_Ocjena  \
# 0           1  Informatika               1            3.83
# 1           2        Pravo               1            4.31
# 5           6     Medicina               1            4.56
# 11         12  Informatika               1            3.00
# 27         28  Strojarstvo               1            2.59
# ..        ...          ...             ...             ...
# 74         75  Strojarstvo               5            1.36
# 97         98        Pravo               5            4.20
# 67         68        Pravo               9            3.21
# 44         45     Medicina              10            2.07
# 92         93        Pravo              12            3.32
#
#     Broj_Polozenih_Ispita      Status
# 0                     8.0  Izvanredan
# 1                     3.0  Izvanredan
# 5                     8.0     Redovan
# 11                    7.0     Redovan
# 27                    7.0  Izvanredan
# ..                    ...         ...
# 74                    7.0   Apsolvent
# 97                   10.0   Zamrznuto
# 67                   11.0     Redovan
# 44                    3.0     Redovan
# 92                    3.0     Redovan
#
# [100 rows x 6 columns]

# %%
plt.hist(uspjeh_studenata2["Godina_Studija"])
# Out:
# (array([49., 14., 17., 17.,  0.,  0.,  0.,  1.,  1.,  1.]),
#  array([ 1. ,  2.1,  3.2,  4.3,  5.4,  6.5,  7.6,  8.7,  9.8, 10.9, 12. ]),
#  <BarContainer object of 10 artists>)

# %%
for col in ['Godina_Studija']:
    uspjeh_studenata2[col] = apply_iqr_capping(uspjeh_studenata2[col])

# %%
uspjeh_studenata2.sort_values (by = ["Godina_Studija"])
# Out:
#     StudentID        Smjer  Godina_Studija  Prosjek_Ocjena  \
# 0           1  Informatika             1.0            3.83
# 1           2        Pravo             1.0            4.31
# 5           6     Medicina             1.0            4.56
# 11         12  Informatika             1.0            3.00
# 27         28  Strojarstvo             1.0            2.59
# ..        ...          ...             ...             ...
# 74         75  Strojarstvo             5.0            1.36
# 97         98        Pravo             5.0            4.20
# 44         45     Medicina             8.5            2.07
# 92         93        Pravo             8.5            3.32
# 67         68        Pravo             8.5            3.21
#
#     Broj_Polozenih_Ispita      Status
# 0                     8.0  Izvanredan
# 1                     3.0  Izvanredan
# 5                     8.0     Redovan
# 11                    7.0     Redovan
# 27                    7.0  Izvanredan
# ..                    ...         ...
# 74                    7.0   Apsolvent
# 97                   10.0   Zamrznuto
# 44                    3.0     Redovan
# 92                    3.0     Redovan
# 67                   11.0     Redovan
#
# [100 rows x 6 columns]

# %%
plt.hist(uspjeh_studenata2["Godina_Studija"])
# Out:
# (array([30., 19., 14.,  0., 17., 17.,  0.,  0.,  0.,  3.]),
#  array([1.  , 1.75, 2.5 , 3.25, 4.  , 4.75, 5.5 , 6.25, 7.  , 7.75, 8.5 ]),
#  <BarContainer object of 10 artists>)

# %%
#### Prosjek ocjena

# %%
uspjeh_studenata2["Prosjek_Ocjena"].mean()
# Out:
# np.float64(3.3925263157894734)

# %%
uspjeh_studenata2["Prosjek_Ocjena"].fillna(value = 3.3925263157894734, inplace = True)
# Out:
# C:\Users\Syntari\AppData\Local\Temp\ipykernel_25136\106568286.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   uspjeh_studenata2["Prosjek_Ocjena"].fillna(value = 3.3925263157894734, inplace = True)

# %%
uspjeh_studenata2
# Out:
#     StudentID        Smjer  Godina_Studija  Prosjek_Ocjena  \
# 0           1  Informatika             1.0        3.830000
# 1           2        Pravo             1.0        4.310000
# 2           3  Informatika             5.0        2.160000
# 3           4    Ekonomija             5.0        3.370000
# 4           5  Informatika             4.0        4.510000
# ..        ...          ...             ...             ...
# 95         96        Pravo             5.0        3.392526
# 96         97     Medicina             1.0        2.280000
# 97         98        Pravo             5.0        4.200000
# 98         99    Ekonomija             4.0        2.880000
# 99        100    Ekonomija             2.0        3.510000
#
#     Broj_Polozenih_Ispita      Status
# 0                     8.0  Izvanredan
# 1                     3.0  Izvanredan
# 2                     3.0     Redovan
# 3                     5.0     Redovan
# 4                     2.0   Apsolvent
# ..                    ...         ...
# 95                    7.0     Redovan
# 96                    3.0     Redovan
# 97                   10.0   Zamrznuto
# 98                    5.0     Redovan
# 99                    4.0     Redovan
#
# [100 rows x 6 columns]

# %%
uspjeh_studenata2.sort_values (by = ["Prosjek_Ocjena"])
# Out:
#     StudentID        Smjer  Godina_Studija  Prosjek_Ocjena  \
# 74         75  Strojarstvo             5.0            1.36
# 21         22  Informatika             5.0            1.70
# 7           8    Ekonomija             5.0            1.76
# 24         25  Strojarstvo             4.0            1.98
# 44         45     Medicina             8.5            2.07
# ..        ...          ...             ...             ...
# 5           6     Medicina             1.0            4.56
# 90         91  Informatika             3.0            4.56
# 79         80  Informatika             5.0            4.60
# 45         46        Pravo             4.0            4.79
# 31         32  Strojarstvo             4.0            5.00
#
#     Broj_Polozenih_Ispita      Status
# 74                    7.0   Apsolvent
# 21                    3.0     Redovan
# 7                     8.0     Redovan
# 24                   12.0     Redovan
# 44                    3.0     Redovan
# ..                    ...         ...
# 5                     8.0     Redovan
# 90                    3.0  Izvanredan
# 79                    5.0     Redovan
# 45                    7.0  Izvanredan
# 31                   13.0  Izvanredan
#
# [100 rows x 6 columns]

# %%
uspjeh_studenata2.isna().sum()
# Out:
# StudentID                0
# Smjer                    0
# Godina_Studija           0
# Prosjek_Ocjena           0
# Broj_Polozenih_Ispita    6
# Status                   0
# dtype: int64

# %%
#### Broj položenih ispita

# %%
Broj_Polozenih_Ispita_median = uspjeh_studenata2["Broj_Polozenih_Ispita"].median()

# %%
uspjeh_studenata2["Broj_Polozenih_Ispita"].fillna(value = Broj_Polozenih_Ispita_median, inplace = True)
# Out:
# C:\Users\Syntari\AppData\Local\Temp\ipykernel_25136\3157861278.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   uspjeh_studenata2["Broj_Polozenih_Ispita"].fillna(value = Broj_Polozenih_Ispita_median, inplace = True)

# %%
### Provjera NaN

# %%
uspjeh_studenata2.isna().sum()
# Out:
# StudentID                0
# Smjer                    0
# Godina_Studija           0
# Prosjek_Ocjena           0
# Broj_Polozenih_Ispita    0
# Status                   0
# dtype: int64

# %%
##### Streaming

# %%
streaming
# Out:
#      Unnamed: 0  KorisnikID  Starost_Korisnika  Broj_Pogledanih_Sati_Mjesecno  \
# 0             0        1001                 52                           13.9
# 1             1        1002                 34                            2.5
# 2             2        1003                 26                           36.4
# 3             3        1004                 21                           44.1
# 4             4        1005                 30                           15.6
# ..          ...         ...                ...                            ...
# 195         195        1196                 21                           10.2
# 196         196        1197                 20                           25.6
# 197         197        1198                 20                           21.9
# 198         198        1199                 21                           10.9
# 199         199        1200                 33                           37.6
#
#      Broj_Uredjaja Tip_Pretplata  Mjesecna_Pretplata_EUR
# 0                2      Standard                   17.48
# 1                1    Obiteljska                   26.62
# 2                4       Premium                   28.42
# 3                1      Standard                   17.06
# 4                1      Standard                   15.47
# ..             ...           ...                     ...
# 195              1       Premium                   24.11
# 196              3       Premium                   22.99
# 197              2      Standard                   14.80
# 198              2      Standard                   14.47
# 199              2       Premium                   24.08
#
# [200 rows x 7 columns]

# %%
streaming.isna().sum()
# Out:
# Unnamed: 0                       0
# KorisnikID                       0
# Starost_Korisnika                0
# Broj_Pogledanih_Sati_Mjesecno    0
# Broj_Uredjaja                    0
# Tip_Pretplata                    0
# Mjesecna_Pretplata_EUR           0
# dtype: int64

# %%
streaming.describe()
# Out:
#        Unnamed: 0   KorisnikID  Starost_Korisnika  \
# count  200.000000   200.000000         200.000000
# mean    99.500000  1100.500000          35.475000
# std     57.879185    57.879185          66.405329
# min      0.000000  1001.000000          -5.000000
# 25%     49.750000  1050.750000          23.750000
# 50%     99.500000  1100.500000          29.000000
# 75%    149.250000  1150.250000          35.000000
# max    199.000000  1200.000000         950.000000
#
#        Broj_Pogledanih_Sati_Mjesecno  Broj_Uredjaja  Mjesecna_Pretplata_EUR
# count                     200.000000       200.0000              200.000000
# mean                       18.419500         2.0400               18.833800
# std                        18.075052         1.2555                4.588201
# min                         1.000000         1.0000                7.990000
# 25%                         6.875000         1.0000               15.520000
# 50%                        13.750000         2.0000               18.250000
# 75%                        23.525000         3.0000               22.055000
# max                       158.500000         5.0000               32.340000

# %%
sns.pairplot(streaming)

# %%
plt.hist(streaming.Starost_Korisnika)
# Out:
# (array([197.,   2.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([ -5. ,  90.5, 186. , 281.5, 377. , 472.5, 568. , 663.5, 759. ,
#         854.5, 950. ]),
#  <BarContainer object of 10 artists>)
