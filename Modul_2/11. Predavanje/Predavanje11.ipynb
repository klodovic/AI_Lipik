# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
penzioneri = pd.read_excel("penzioneri.xlsx", sheet_name = "drugi")
nekretnine_zg = pd.read_csv("nekretnine_zagreb.csv")

# %%
penzioneri
# Out:
#       grad  starost  zanimanje spol  primanja  stednja
# 0    Split     55.0    obrtnik    m    2500.0  10000.0
# 1   Zagreb     77.0  penzioner    m    1700.0   5000.0
# 2    Split     62.0  penzioner    m    1800.0   2000.0
# 3   Zagreb      NaN    obrtnik    f    3500.0   4500.0
# 4    Split     59.0        NaN  NaN       NaN      NaN
# 5   Zagreb     71.0  penzioner    m    1250.0   6500.0
# 6   Osijek     59.0    obrtnik    m    4000.0  12000.0
# 7     Pula      NaN    obrtnik  NaN    3000.0  10000.0
# 8   Zagreb     65.0        NaN    m    2000.0   7000.0
# 9    Split     52.0    obrtnik    m    5000.0      NaN
# 10  Zagreb     60.0  penzioner    f    1700.0   2500.0
# 11    Pula      NaN    obrtnik    m    4500.0      NaN
# 12  Osijek     58.0    obrtnik    f    3000.0  11000.0
# 13  Zagreb     83.0  penzioner    m    3500.0  14000.0
# 14   Split     74.0    obrtnik    f    4900.0  16000.0
# 15  Zagreb     92.0  penzioner    m    6000.0  20000.0
# ...

# %%
penzioneri.isnull().sum()
# Out:
# grad         0
# starost      3
# zanimanje    2
# spol         2
# primanja     1
# stednja      3
# dtype: int64

# %%
penzioneri.describe()
# Out:
#          starost     primanja       stednja
# count  18.000000    20.000000     18.000000
# mean   67.111111  3882.500000  11227.777778
# std    10.681974  1823.622407   8040.105761
# min    52.000000  1250.000000   2000.000000
# 25%    59.000000  2375.000000   6275.000000
# 50%    63.500000  3750.000000   9600.000000
# 75%    74.750000  4925.000000  13500.000000
# max    92.000000  8200.000000  33000.000000

# %%
isna_values = penzioneri[penzioneri.isna().any(axis=1)]
isna_values
# Out:
#       grad  starost zanimanje spol  primanja  stednja
# 3   Zagreb      NaN   obrtnik    f    3500.0   4500.0
# 4    Split     59.0       NaN  NaN       NaN      NaN
# 7     Pula      NaN   obrtnik  NaN    3000.0  10000.0
# 8   Zagreb     65.0       NaN    m    2000.0   7000.0
# 9    Split     52.0   obrtnik    m    5000.0      NaN
# 11    Pula      NaN   obrtnik    m    4500.0      NaN

# %%
penzioneri2 = penzioneri.copy()

# %%
penzioneri2.dropna(how="any")
# Out:
#       grad  starost  zanimanje spol  primanja  stednja
# 0    Split     55.0    obrtnik    m    2500.0  10000.0
# 1   Zagreb     77.0  penzioner    m    1700.0   5000.0
# 2    Split     62.0  penzioner    m    1800.0   2000.0
# 5   Zagreb     71.0  penzioner    m    1250.0   6500.0
# 6   Osijek     59.0    obrtnik    m    4000.0  12000.0
# 10  Zagreb     60.0  penzioner    f    1700.0   2500.0
# 12  Osijek     58.0    obrtnik    f    3000.0  11000.0
# 13  Zagreb     83.0  penzioner    m    3500.0  14000.0
# 14   Split     74.0    obrtnik    f    4900.0  16000.0
# 15  Zagreb     92.0  penzioner    m    6000.0  20000.0
# 16  Osijek     62.0    obrtnik    m    5200.0   6200.0
# 17    Pula     69.0    obrtnik    m    4700.0   9200.0
# 18  Osijek     76.0    obrtnik    m    4900.0   8200.0
# 19  Zagreb     59.0    obrtnik    f    6300.0  25000.0
# 20  Zagreb     75.0  penzioner    m    8200.0  33000.0

# %%
penzioneri2
# Out:
#       grad  starost  zanimanje spol  primanja  stednja
# 0    Split     55.0    obrtnik    m    2500.0  10000.0
# 1   Zagreb     77.0  penzioner    m    1700.0   5000.0
# 2    Split     62.0  penzioner    m    1800.0   2000.0
# 3   Zagreb      NaN    obrtnik    f    3500.0   4500.0
# 4    Split     59.0        NaN  NaN       NaN      NaN
# 5   Zagreb     71.0  penzioner    m    1250.0   6500.0
# 6   Osijek     59.0    obrtnik    m    4000.0  12000.0
# 7     Pula      NaN    obrtnik  NaN    3000.0  10000.0
# 8   Zagreb     65.0        NaN    m    2000.0   7000.0
# 9    Split     52.0    obrtnik    m    5000.0      NaN
# 10  Zagreb     60.0  penzioner    f    1700.0   2500.0
# 11    Pula      NaN    obrtnik    m    4500.0      NaN
# 12  Osijek     58.0    obrtnik    f    3000.0  11000.0
# 13  Zagreb     83.0  penzioner    m    3500.0  14000.0
# 14   Split     74.0    obrtnik    f    4900.0  16000.0
# 15  Zagreb     92.0  penzioner    m    6000.0  20000.0
# ...

# %%
penzioneri2.dropna(how="any", inplace=True)

# %%
penzioneri2
# Out:
#       grad  starost  zanimanje spol  primanja  stednja
# 0    Split     55.0    obrtnik    m    2500.0  10000.0
# 1   Zagreb     77.0  penzioner    m    1700.0   5000.0
# 2    Split     62.0  penzioner    m    1800.0   2000.0
# 5   Zagreb     71.0  penzioner    m    1250.0   6500.0
# 6   Osijek     59.0    obrtnik    m    4000.0  12000.0
# 10  Zagreb     60.0  penzioner    f    1700.0   2500.0
# 12  Osijek     58.0    obrtnik    f    3000.0  11000.0
# 13  Zagreb     83.0  penzioner    m    3500.0  14000.0
# 14   Split     74.0    obrtnik    f    4900.0  16000.0
# 15  Zagreb     92.0  penzioner    m    6000.0  20000.0
# 16  Osijek     62.0    obrtnik    m    5200.0   6200.0
# 17    Pula     69.0    obrtnik    m    4700.0   9200.0
# 18  Osijek     76.0    obrtnik    m    4900.0   8200.0
# 19  Zagreb     59.0    obrtnik    f    6300.0  25000.0
# 20  Zagreb     75.0  penzioner    m    8200.0  33000.0

# %%
#### Metoda 2

# %%
penzioneri3 = penzioneri.copy()

# %%
penzioneri3
# Out:
#       grad  starost  zanimanje spol  primanja  stednja
# 0    Split     55.0    obrtnik    m    2500.0  10000.0
# 1   Zagreb     77.0  penzioner    m    1700.0   5000.0
# 2    Split     62.0  penzioner    m    1800.0   2000.0
# 3   Zagreb      NaN    obrtnik    f    3500.0   4500.0
# 4    Split     59.0        NaN  NaN       NaN      NaN
# 5   Zagreb     71.0  penzioner    m    1250.0   6500.0
# 6   Osijek     59.0    obrtnik    m    4000.0  12000.0
# 7     Pula      NaN    obrtnik  NaN    3000.0  10000.0
# 8   Zagreb     65.0        NaN    m    2000.0   7000.0
# 9    Split     52.0    obrtnik    m    5000.0      NaN
# 10  Zagreb     60.0  penzioner    f    1700.0   2500.0
# 11    Pula      NaN    obrtnik    m    4500.0      NaN
# 12  Osijek     58.0    obrtnik    f    3000.0  11000.0
# 13  Zagreb     83.0  penzioner    m    3500.0  14000.0
# 14   Split     74.0    obrtnik    f    4900.0  16000.0
# 15  Zagreb     92.0  penzioner    m    6000.0  20000.0
# ...

# %%
### brišemo samo redak 4 s najviše NaN vrijednosti

# %%
penzioneri3.dropna(thresh = 5, inplace = True)
penzioneri3
# Out:
#       grad  starost  zanimanje spol  primanja  stednja
# 0    Split     55.0    obrtnik    m    2500.0  10000.0
# 1   Zagreb     77.0  penzioner    m    1700.0   5000.0
# 2    Split     62.0  penzioner    m    1800.0   2000.0
# 3   Zagreb      NaN    obrtnik    f    3500.0   4500.0
# 5   Zagreb     71.0  penzioner    m    1250.0   6500.0
# 6   Osijek     59.0    obrtnik    m    4000.0  12000.0
# 8   Zagreb     65.0        NaN    m    2000.0   7000.0
# 9    Split     52.0    obrtnik    m    5000.0      NaN
# 10  Zagreb     60.0  penzioner    f    1700.0   2500.0
# 12  Osijek     58.0    obrtnik    f    3000.0  11000.0
# 13  Zagreb     83.0  penzioner    m    3500.0  14000.0
# 14   Split     74.0    obrtnik    f    4900.0  16000.0
# 15  Zagreb     92.0  penzioner    m    6000.0  20000.0
# 16  Osijek     62.0    obrtnik    m    5200.0   6200.0
# 17    Pula     69.0    obrtnik    m    4700.0   9200.0
# 18  Osijek     76.0    obrtnik    m    4900.0   8200.0
# ...

# %%
#### Preporuka  - brišemo samo 1-2% podataka

# %%
penzioneri4 = penzioneri.copy()

# %%
prosjek_godina = penzioneri4 ["starost"].mean()
prosjek_godina
# Out:
# np.float64(67.11111111111111)

# %%
penzioneri4 ["starost"].fillna (prosjek_godina, inplace = True)
penzioneri4
# Out:
# C:\Users\Syntari\AppData\Local\Temp\ipykernel_19396\3626329026.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   penzioneri4 ["starost"].fillna (prosjek_godina, inplace = True)
#       grad    starost  zanimanje spol  primanja  stednja
# 0    Split  55.000000    obrtnik    m    2500.0  10000.0
# 1   Zagreb  77.000000  penzioner    m    1700.0   5000.0
# 2    Split  62.000000  penzioner    m    1800.0   2000.0
# 3   Zagreb  67.111111    obrtnik    f    3500.0   4500.0
# ...

# %%
penzioneri4["spol"].mode()
# Out:
# 0    m
# Name: spol, dtype: object

# %%
penzioneri4 ["spol"].fillna(value = "m", inplace = True)
# Out:
# C:\Users\Syntari\AppData\Local\Temp\ipykernel_19396\1655676017.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   penzioneri4 ["spol"].fillna(value = "m", inplace = True)

# %%
penzioneri4["zanimanje"].mode()
# Out:
# 0    obrtnik
# Name: zanimanje, dtype: object

# %%
penzioneri4 ["zanimanje"].fillna(value = "obrtnik", inplace = True)
# Out:
# C:\Users\Syntari\AppData\Local\Temp\ipykernel_19396\1007816099.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   penzioneri4 ["zanimanje"].fillna(value = "obrtnik", inplace = True)

# %%
penzioneri4
# Out:
#       grad    starost  zanimanje spol  primanja  stednja
# 0    Split  55.000000    obrtnik    m    2500.0  10000.0
# 1   Zagreb  77.000000  penzioner    m    1700.0   5000.0
# 2    Split  62.000000  penzioner    m    1800.0   2000.0
# 3   Zagreb  67.111111    obrtnik    f    3500.0   4500.0
# 4    Split  59.000000    obrtnik    m       NaN      NaN
# 5   Zagreb  71.000000  penzioner    m    1250.0   6500.0
# 6   Osijek  59.000000    obrtnik    m    4000.0  12000.0
# 7     Pula  67.111111    obrtnik    m    3000.0  10000.0
# 8   Zagreb  65.000000    obrtnik    m    2000.0   7000.0
# 9    Split  52.000000    obrtnik    m    5000.0      NaN
# 10  Zagreb  60.000000  penzioner    f    1700.0   2500.0
# 11    Pula  67.111111    obrtnik    m    4500.0      NaN
# 12  Osijek  58.000000    obrtnik    f    3000.0  11000.0
# 13  Zagreb  83.000000  penzioner    m    3500.0  14000.0
# 14   Split  74.000000    obrtnik    f    4900.0  16000.0
# ...

# %%
primanja = penzioneri4["primanja"].median()

# %%
penzioneri4 ["primanja"].fillna(value = primanja, inplace = True)
# Out:
# C:\Users\Syntari\AppData\Local\Temp\ipykernel_19396\2487636353.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   penzioneri4 ["primanja"].fillna(value = primanja, inplace = True)

# %%
penzioneri4
# Out:
#       grad    starost  zanimanje spol  primanja  stednja
# 0    Split  55.000000    obrtnik    m    2500.0  10000.0
# 1   Zagreb  77.000000  penzioner    m    1700.0   5000.0
# 2    Split  62.000000  penzioner    m    1800.0   2000.0
# 3   Zagreb  67.111111    obrtnik    f    3500.0   4500.0
# 4    Split  59.000000    obrtnik    m    3750.0      NaN
# 5   Zagreb  71.000000  penzioner    m    1250.0   6500.0
# 6   Osijek  59.000000    obrtnik    m    4000.0  12000.0
# 7     Pula  67.111111    obrtnik    m    3000.0  10000.0
# 8   Zagreb  65.000000    obrtnik    m    2000.0   7000.0
# 9    Split  52.000000    obrtnik    m    5000.0      NaN
# 10  Zagreb  60.000000  penzioner    f    1700.0   2500.0
# 11    Pula  67.111111    obrtnik    m    4500.0      NaN
# 12  Osijek  58.000000    obrtnik    f    3000.0  11000.0
# 13  Zagreb  83.000000  penzioner    m    3500.0  14000.0
# 14   Split  74.000000    obrtnik    f    4900.0  16000.0
# ...

# %%
stednja = penzioneri4["stednja"].mean()

# %%
penzioneri4 ["stednja"].fillna(value = stednja, inplace = True)
# Out:
# C:\Users\Syntari\AppData\Local\Temp\ipykernel_19396\1734812827.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   penzioneri4 ["stednja"].fillna(value = stednja, inplace = True)

# %%
penzioneri4
# Out:
#       grad    starost  zanimanje spol  primanja       stednja
# 0    Split  55.000000    obrtnik    m    2500.0  10000.000000
# 1   Zagreb  77.000000  penzioner    m    1700.0   5000.000000
# 2    Split  62.000000  penzioner    m    1800.0   2000.000000
# 3   Zagreb  67.111111    obrtnik    f    3500.0   4500.000000
# 4    Split  59.000000    obrtnik    m    3750.0  11227.777778
# 5   Zagreb  71.000000  penzioner    m    1250.0   6500.000000
# 6   Osijek  59.000000    obrtnik    m    4000.0  12000.000000
# 7     Pula  67.111111    obrtnik    m    3000.0  10000.000000
# 8   Zagreb  65.000000    obrtnik    m    2000.0   7000.000000
# 9    Split  52.000000    obrtnik    m    5000.0  11227.777778
# 10  Zagreb  60.000000  penzioner    f    1700.0   2500.000000
# 11    Pula  67.111111    obrtnik    m    4500.0  11227.777778
# 12  Osijek  58.000000    obrtnik    f    3000.0  11000.000000
# 13  Zagreb  83.000000  penzioner    m    3500.0  14000.000000
# ...

# %%
#### Nekretnine

# %%
nekretnine_zg
# Out:
#     Unnamed: 0        Kvart    Tip_Nekretnine  Kvadratura_m2  Broj_Soba  \
# 0            0   Trešnjevka              Stan           79.0          1
# 1            1  Novi Zagreb              Stan           69.0          5
# 2            2  Novi Zagreb              Stan           51.0          5
# 3            3     Maksimir              Stan           57.0          4
# 4            4   Trešnjevka  Poslovni Prostor           74.0          2
# ..         ...          ...               ...            ...        ...
# 95          95     Maksimir              Stan           73.0          5
# 96          96   Trešnjevka              Stan           78.0          5
# 97          97     Maksimir              Kuća           80.0          2
# 98          98       Centar              Stan           76.0          5
# 99          99   Trešnjevka              Stan           51.0          1
#
#     Godina_Izgradnje  Cijena_EUR Datum_Objave_Oglasa
# ...

# %%
nekretnine_zg.describe()
# Out:
#        Unnamed: 0  Kvadratura_m2   Broj_Soba  Godina_Izgradnje    Cijena_EUR
# count  100.000000      92.000000  100.000000         93.000000  1.000000e+02
# mean    49.500000      66.956522    3.450000       1979.987316  1.932400e+05
# std     29.011492      20.480982    2.152635         19.974325  5.489004e+05
# min      0.000000      20.000000    1.000000       1927.476226  1.000000e+03
# 25%     24.750000      52.000000    2.000000       1967.566714  5.775000e+04
# 50%     49.500000      67.000000    3.000000       1981.793418  9.050000e+04
# 75%     74.250000      79.250000    5.000000       1993.508872  1.490000e+05
# max     99.000000     113.000000   15.000000       2023.652623  5.000000e+06

# %%
nekretnine_zg.isna().sum()
# Out:
# Unnamed: 0              0
# Kvart                  10
# Tip_Nekretnine          0
# Kvadratura_m2           8
# Broj_Soba               0
# Godina_Izgradnje        7
# Cijena_EUR              0
# Datum_Objave_Oglasa    15
# dtype: int64

# %%
nekretnine_zg["Datum_Objave_Oglasa"] = nekretnine_zg["Datum_Objave_Oglasa"].ffill()

# %%
nekretnine_zg
# Out:
#     Unnamed: 0        Kvart    Tip_Nekretnine  Kvadratura_m2  Broj_Soba  \
# 0            0   Trešnjevka              Stan           79.0          1
# 1            1  Novi Zagreb              Stan           69.0          5
# 2            2  Novi Zagreb              Stan           51.0          5
# 3            3     Maksimir              Stan           57.0          4
# 4            4   Trešnjevka  Poslovni Prostor           74.0          2
# ..         ...          ...               ...            ...        ...
# 95          95     Maksimir              Stan           73.0          5
# 96          96   Trešnjevka              Stan           78.0          5
# 97          97     Maksimir              Kuća           80.0          2
# 98          98       Centar              Stan           76.0          5
# 99          99   Trešnjevka              Stan           51.0          1
#
#     Godina_Izgradnje  Cijena_EUR Datum_Objave_Oglasa
# ...

# %%
sns.pairplot(nekretnine_zg)

# %%
nekretnine_zg.isna().sum()
# Out:
# Unnamed: 0              0
# Kvart                  10
# Tip_Nekretnine          0
# Kvadratura_m2           8
# Broj_Soba               0
# Godina_Izgradnje        7
# Cijena_EUR              0
# Datum_Objave_Oglasa     0
# dtype: int64

# %%
nekretnine_zg.sort_values (by = ["Broj_Soba"])
# Out:
#     Unnamed: 0        Kvart Tip_Nekretnine  Kvadratura_m2  Broj_Soba  \
# 0            0   Trešnjevka           Stan           79.0          1
# 31          31          NaN           Stan           67.0          1
# 21          21  Novi Zagreb           Stan           32.0          1
# 17          17    Kustošija           Stan          100.0          1
# 24          24      Dubrava           Stan           20.0          1
# ..         ...          ...            ...            ...        ...
# 84          84   Trešnjevka           Stan          103.0          5
# 98          98       Centar           Stan           76.0          5
# 58          58  Novi Zagreb           Stan           20.0         10
# 51          51     Maksimir           Kuća           64.0         12
# 6            6       Centar           Stan            NaN         15
#
#     Godina_Izgradnje  Cijena_EUR Datum_Objave_Oglasa
# 0        1953.028278     70000.0          2023-01-01
# ...

# %%
nekretnine_zg2 = nekretnine_zg.copy()

# %%
def apply_iqr_capping(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Primjena cappinga
    # Sve vrijednosti manje od donje granice postaju donja granica
    # Sve vrijednosti veće od gornje granice postaju gornja granica
    capped_series = series.clip(lower=lower_bound, upper=upper_bound)
    return capped_series

# %%
for col in ['Broj_Soba']:
    nekretnine_zg2[col] = apply_iqr_capping(nekretnine_zg2[col])

# %%
nekretnine_zg2.sort_values (by = ["Broj_Soba"])
# Out:
#     Unnamed: 0        Kvart    Tip_Nekretnine  Kvadratura_m2  Broj_Soba  \
# 0            0   Trešnjevka              Stan           79.0      3.365
# 1            1  Novi Zagreb              Stan           69.0      3.365
# 2            2  Novi Zagreb              Stan           51.0      3.365
# 3            3     Maksimir              Stan           57.0      3.365
# 4            4   Trešnjevka  Poslovni Prostor           74.0      3.365
# ..         ...          ...               ...            ...        ...
# 95          95     Maksimir              Stan           73.0      3.365
# 96          96   Trešnjevka              Stan           78.0      3.365
# 97          97     Maksimir              Kuća           80.0      3.365
# 98          98       Centar              Stan           76.0      3.365
# 99          99   Trešnjevka              Stan           51.0      3.365
#
#     Godina_Izgradnje  Cijena_EUR Datum_Objave_Oglasa
# ...

# %%
nekretnine_zg2.isna().sum()
# Out:
# Unnamed: 0              0
# Kvart                  10
# Tip_Nekretnine          0
# Kvadratura_m2           8
# Broj_Soba               0
# Godina_Izgradnje        7
# Cijena_EUR              0
# Datum_Objave_Oglasa     0
# dtype: int64

# %%
nekretnine_zg2["Godina_Izgradnje"] = nekretnine_zg2["Godina_Izgradnje"].ffill()
nekretnine_zg2
# Out:
#     Unnamed: 0        Kvart    Tip_Nekretnine  Kvadratura_m2  Broj_Soba  \
# 0            0   Trešnjevka              Stan           79.0        1.0
# 1            1  Novi Zagreb              Stan           69.0        5.0
# 2            2  Novi Zagreb              Stan           51.0        5.0
# 3            3     Maksimir              Stan           57.0        4.0
# 4            4   Trešnjevka  Poslovni Prostor           74.0        2.0
# ..         ...          ...               ...            ...        ...
# 95          95     Maksimir              Stan           73.0        5.0
# 96          96   Trešnjevka              Stan           78.0        5.0
# 97          97     Maksimir              Kuća           80.0        2.0
# 98          98       Centar              Stan           76.0        5.0
# 99          99   Trešnjevka              Stan           51.0        1.0
#
#     Godina_Izgradnje  Cijena_EUR Datum_Objave_Oglasa
# ...

# %%
nekretnine_zg2.isna().sum()
# Out:
# Unnamed: 0              0
# Kvart                  10
# Tip_Nekretnine          0
# Kvadratura_m2           8
# Broj_Soba               0
# Godina_Izgradnje        0
# Cijena_EUR              0
# Datum_Objave_Oglasa     0
# dtype: int64

# %%
nekretnine_zg2.sort_values (by = ["Kvadratura_m2"]).head(99)
# Out:
#     Unnamed: 0        Kvart    Tip_Nekretnine  Kvadratura_m2  Broj_Soba  \
# 24          24      Dubrava              Stan           20.0        1.0
# 58          58  Novi Zagreb              Stan           20.0        9.5
# 23          23      Dubrava              Kuća           26.0        2.0
# 52          52       Centar              Stan           27.0        5.0
# 21          21  Novi Zagreb              Stan           32.0        1.0
# ..         ...          ...               ...            ...        ...
# 43          43   Trešnjevka              Stan            NaN        3.0
# 46          46       Centar              Stan            NaN        4.0
# 48          48     Maksimir              Stan            NaN        5.0
# 56          56      Dubrava  Poslovni Prostor            NaN        1.0
# 78          78       Centar              Stan            NaN        4.0
#
#     Godina_Izgradnje  Cijena_EUR Datum_Objave_Oglasa
# ...

# %%
nekretnine_zg2["Kvadratura_m2"].mean()
# Out:
# np.float64(66.95652173913044)

# %%
nekretnine_zg2 ["Kvadratura_m2"].fillna(value = 66.95, inplace = True)
# Out:
# C:\Users\Syntari\AppData\Local\Temp\ipykernel_19396\1872313559.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nekretnine_zg2 ["Kvadratura_m2"].fillna(value = 66.95, inplace = True)

# %%
nekretnine_zg2
# Out:
#     Unnamed: 0        Kvart    Tip_Nekretnine  Kvadratura_m2  Broj_Soba  \
# 0            0   Trešnjevka              Stan           79.0        1.0
# 1            1  Novi Zagreb              Stan           69.0        5.0
# 2            2  Novi Zagreb              Stan           51.0        5.0
# 3            3     Maksimir              Stan           57.0        4.0
# 4            4   Trešnjevka  Poslovni Prostor           74.0        2.0
# ..         ...          ...               ...            ...        ...
# 95          95     Maksimir              Stan           73.0        5.0
# 96          96   Trešnjevka              Stan           78.0        5.0
# 97          97     Maksimir              Kuća           80.0        2.0
# 98          98       Centar              Stan           76.0        5.0
# 99          99   Trešnjevka              Stan           51.0        1.0
#
#     Godina_Izgradnje  Cijena_EUR Datum_Objave_Oglasa
# ...

# %%
nekretnine_zg2.isna().sum()
# Out:
# Unnamed: 0             0
# Kvart                  0
# Tip_Nekretnine         0
# Kvadratura_m2          0
# Broj_Soba              0
# Godina_Izgradnje       0
# Cijena_EUR             0
# Datum_Objave_Oglasa    0
# dtype: int64

# %%
nekretnine_zg2["Kvart"].mode()
# Out:
# 0    Maksimir
# Name: Kvart, dtype: object

# %%
nekretnine_zg2 ["Kvart"].fillna(value = "Maksimir", inplace = True)

# %%
nekretnine_zg2
# Out:
#     Unnamed: 0        Kvart    Tip_Nekretnine  Kvadratura_m2  Broj_Soba  \
# 0            0   Trešnjevka              Stan           79.0        1.0
# 1            1  Novi Zagreb              Stan           69.0        5.0
# 2            2  Novi Zagreb              Stan           51.0        5.0
# 3            3     Maksimir              Stan           57.0        4.0
# 4            4   Trešnjevka  Poslovni Prostor           74.0        2.0
# ..         ...          ...               ...            ...        ...
# 95          95     Maksimir              Stan           73.0        5.0
# 96          96   Trešnjevka              Stan           78.0        5.0
# 97          97     Maksimir              Kuća           80.0        2.0
# 98          98       Centar              Stan           76.0        5.0
# 99          99   Trešnjevka              Stan           51.0        1.0
#
#     Godina_Izgradnje  Cijena_EUR Datum_Objave_Oglasa
# ...

# %%
nekretnine_zg2.isnull().sum()
# Out:
# Unnamed: 0             0
# Kvart                  0
# Tip_Nekretnine         0
# Kvadratura_m2          0
# Broj_Soba              0
# Godina_Izgradnje       0
# Cijena_EUR             0
# Datum_Objave_Oglasa    0
# dtype: int64
