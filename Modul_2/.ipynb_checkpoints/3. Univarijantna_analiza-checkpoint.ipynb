# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("osiguranici.csv")

# %%
df.head(10)
# Out:
#      City  Gender  Age   Income Illness
# 0  Dallas    Male   41  40367.0      No
# 1  Dallas    Male   54  45084.0      No
# 2  Dallas    Male   42  52483.0      No
# 3  Dallas    Male   40  40941.0      No
# 4  Dallas    Male   46  50289.0      No
# 5  Dallas  Female   36  50786.0      No
# 6  Dallas  Female   32  33155.0      No
# 7  Dallas    Male   39  30914.0      No
# 8  Dallas    Male   51  68667.0      No
# 9  Dallas  Female   30  50082.0      No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   City     150000 non-null  object
#  1   Gender   150000 non-null  object
#  2   Age      150000 non-null  int64
#  3   Income   150000 non-null  float64
#  4   Illness  150000 non-null  object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 5.7+ MB

# %%
df.describe()
# Out:
#                  Age         Income
# count  150000.000000  150000.000000
# mean       44.950200   91252.798273
# std        11.572486   24989.500948
# min        25.000000    -654.000000
# 25%        35.000000   80867.750000
# 50%        45.000000   93655.000000
# 75%        55.000000  104519.000000
# max        65.000000  177157.000000

# %%
plt.hist(df.Income)
# Out:
# (array([  141.,  3384., 11501.,  9873., 31508., 60095., 20961.,  8463.,
#          3882.,   192.]),
#  array([  -654. ,  17127.1,  34908.2,  52689.3,  70470.4,  88251.5,
#         106032.6, 123813.7, 141594.8, 159375.9, 177157. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.Income, bins=20)
# Out:
# (array([1.1000e+01, 1.3000e+02, 7.3900e+02, 2.6450e+03, 5.3440e+03,
#         6.1570e+03, 5.0270e+03, 4.8460e+03, 9.9110e+03, 2.1597e+04,
#         3.1464e+04, 2.8631e+04, 1.5182e+04, 5.7790e+03, 4.1650e+03,
#         4.2980e+03, 2.9150e+03, 9.6700e+02, 1.7300e+02, 1.9000e+01]),
#  array([  -654.  ,   8236.55,  17127.1 ,  26017.65,  34908.2 ,  43798.75,
#          52689.3 ,  61579.85,  70470.4 ,  79360.95,  88251.5 ,  97142.05,
#         106032.6 , 114923.15, 123813.7 , 132704.25, 141594.8 , 150485.35,
#         159375.9 , 168266.45, 177157.  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df.Income, bins=20)
plt.xlabel("Iznos place")
plt.ylabel("Broj osiguranika")
plt.title("Distribucija primanja")
# Out:
# Text(0.5, 1.0, 'Distribucija primanja')

# %%
plt.hist(df.Age)
# Out:
# (array([13374., 15044., 14917., 14920., 15266., 14893., 14936., 14851.,
#         14851., 16948.]),
#  array([25., 29., 33., 37., 41., 45., 49., 53., 57., 61., 65.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.Age, bins=20)
# Out:
# (array([5786., 7588., 7536., 7508., 7479., 7438., 7505., 7415., 7622.,
#         7644., 7377., 7516., 7454., 7482., 7562., 7289., 7494., 7357.,
#         7421., 9527.]),
#  array([25., 27., 29., 31., 33., 35., 37., 39., 41., 43., 45., 47., 49.,
#         51., 53., 55., 57., 59., 61., 63., 65.]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df.Age, bins=20)
plt.xlabel("Godine osiguranika")
plt.ylabel("Broj osiguranika")
plt.title("Distribucija prema godinama")
# Out:
# Text(0.5, 1.0, 'Distribucija prema godinama')

# %%
df['Gender'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Illness'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
plt.hist(titanic.Fare, bins=20)
plt.xlabel("Cijena karata")
plt.ylabel("Broj putnika")
plt.title("Distribucija prema cijeni karte")
# Out:
# Text(0.5, 1.0, 'Distribucija prema cijeni karte')

# %%
plt.hist(titanic.Age, bins=20)
plt.xlabel("Starost putnika")
plt.ylabel("Broj putnika")
plt.title("Distribucija prema starosti putnika")
# Out:
# Text(0.5, 1.0, 'Distribucija prema starosti putnika')

# %%
titanic['Survived'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(titanic.Fare, bins=20)
plt.xlabel("Cijena karata")
plt.ylabel("Broj putnika")
plt.title("Distribucija prema cijeni karte")
# Out:
# Text(0.5, 1.0, 'Distribucija prema cijeni karte')

# %%
titanic['Fare_Log_Transformed'] = np.log1p(titanic['Fare']) #prirodni log na cijenu karte

# %%
titanic.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare  \
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500
#
#    Fare_Log_Transformed
# 0              2.110213
# 1              4.280593
# ...

# %%
plt.hist (titanic.Fare_Log_Transformed, bins = 20)
# Out:
# (array([ 15.,   0.,   0.,   0.,   0.,   2., 166., 181., 107.,  59., 117.,
#          65.,  46.,  39.,  39.,  20.,  11.,  17.,   0.,   3.]),
#  array([0.        , 0.31204587, 0.62409174, 0.9361376 , 1.24818347,
#         1.56022934, 1.87227521, 2.18432107, 2.49636694, 2.80841281,
#         3.12045868, 3.43250455, 3.74455041, 4.05659628, 4.36864215,
#         4.68068802, 4.99273388, 5.30477975, 5.61682562, 5.92887149,
#         6.24091735]),
#  <BarContainer object of 20 artists>)

# %%
df["Income"].hist(by = df["Gender"], bins = 15)
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
df["Income"].hist(by = df["Illness"], bins = 15)
# Out:
# array([<Axes: title={'center': 'No'}>, <Axes: title={'center': 'Yes'}>],
#       dtype=object)

# %%
titanic["Age"].hist(by = titanic["Pclass"], bins = 15)
# Out:
# array([[<Axes: title={'center': '1'}>, <Axes: title={'center': '2'}>],
#        [<Axes: title={'center': '3'}>, <Axes: >]], dtype=object)

# %%
titanic["Age"].hist(by = titanic["Survived"], bins = 15)
# Out:
# array([<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#       dtype=object)
