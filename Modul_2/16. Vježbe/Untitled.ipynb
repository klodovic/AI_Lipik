# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats

from sklearn.preprocessing import LabelEncoder

# %%
polaznici = pd.read_csv("df_polaznici.csv")
tecajevi = pd.read_csv("df_tecajevi.csv")
upisi = pd.read_csv("df_upisi.csv")

# %%
polaznici
tecajevi
upisi
# Out:
#      UpisID  PolaznikID  TecajID Datum_Upisa Status_Upisa
# 0        10      1156.0   5095.0  07/20/2023      Aktivan
# 1        41      1400.0   6202.0  11-10-2023      Završen
# 2       456      1065.0   5091.0  07/10/2024   Na čekanju
# 3       404      1314.0   5033.0  2023-11-12      Završen
# 4       592      1272.0   5090.0  24-02-2022      Aktivan
# ..      ...         ...      ...         ...          ...
# 610     424      1048.0   5047.0  06/13/2024      Aktivan
# 611     533      1119.0   5012.0  09/25/2022      Aktivan
# 612     224      1149.0   5044.0  27-10-2023      Aktivan
# 613      70      1088.0   5084.0  18-05-2024      Aktivan
# 614      16      1064.0      NaN  03-07-2024      Aktivan
#
# [615 rows x 5 columns]

# %%
### merge tablica polaznici i upisi

# %%
polaznici_upisi = pd.merge (polaznici, upisi, on ="PolaznikID", how = "inner")

# %%
### merge prethodne tablice i upisi

# %%
polaznici_UT = pd.merge (polaznici_upisi, tecajevi, on ="TecajID", how = "inner")

# %%
#### dodajemo novu kolonu koja računa starost polaznika

# %%
polaznici_UT['Starost'] = 2025 - polaznici_UT['Godina_Rodjenja']

# %%
polaznici_UT
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme  UpisID  \
# 0          1377             1979            Europa      Španjolski     495
# 1          1221             1973            Europa       Francuski     168
# 2          1221             1973            Europa       Francuski     449
# 3          1221             1973            Europa       Francuski     335
# 4          1221             1973            Europa       Francuski      30
# ..          ...              ...               ...             ...     ...
# 546        1044             1952               NaN        Engleski      58
# 547        1126             1991             Azija        Engleski     112
# 548        1186             1971  Sjeverna Amerika      Španjolski     398
# 549        1035             1991  Sjeverna Amerika        Engleski     313
# 550        1035             1991  Sjeverna Amerika        Engleski     153
#
#      TecajID Datum_Upisa Status_Upisa            Naziv_Tecaja    Razina  \
# 0     5089.0  12-08-2024      Završen         Cloud Computing   Srednji
# 1     5068.0  2022-03-05      Završen   Strojno učenje osnove   Srednji
# 2     5083.0  2024-06-16      Aktivan         Cloud Computing  Napredni
# 3     5025.0  26-09-2022      Aktivan           Uvod u Python   Početni
# 4     5033.0  2023-11-11      Aktivan       Data Storytelling   Početni
# ..       ...         ...          ...                     ...       ...
# 546   5094.0  2022-12-25      Odustao        Excel za analizu   Početni
# 547   5081.0  04/24/2023      Završen  Vizualizacija podataka   početni
# 548   5001.0  03/03/2024   Na čekanju  Vizualizacija podataka   Srednji
# 549   5095.0  03/02/2024      Aktivan           Uvod u Python   Početni
# 550   5007.0  01/31/2022      Aktivan   Strojno učenje osnove   Srednji
#
#      Trajanje_Sati  Cijena_USD  Starost
# 0             19.1       20.00       46
# 1             30.6       81.00       52
# 2             22.5       61.05       52
# 3              NaN       66.03       52
# 4             30.6         NaN       52
# ..             ...         ...      ...
# 546           31.8      121.47       73
# 547           31.5      136.03       34
# 548           40.2      185.49       54
# 549           42.7      100.04       34
# 550           20.6       82.92       34
#
# [551 rows x 13 columns]

# %%
polaznici_UT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551 entries, 0 to 550
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PolaznikID       551 non-null    int64
#  1   Godina_Rodjenja  551 non-null    int64
#  2   Regija           522 non-null    object
#  3   Jezik_Platforme  551 non-null    object
#  4   UpisID           551 non-null    int64
#  5   TecajID          551 non-null    float64
#  6   Datum_Upisa      548 non-null    object
#  7   Status_Upisa     551 non-null    object
#  8   Naziv_Tecaja     551 non-null    object
#  9   Razina           551 non-null    object
#  10  Trajanje_Sati    491 non-null    float64
#  11  Cijena_USD       497 non-null    float64
#  12  Starost          551 non-null    int64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 56.1+ KB

# %%
### Zaključak: imamo 551 zapis, ali i neke kolone s praznim ćelijama

# %%
polaznici_UT.describe()
# Out:
#         PolaznikID  Godina_Rodjenja      UpisID     TecajID  Trajanje_Sati  \
# count   551.000000       551.000000  551.000000   551.00000     491.000000
# mean   1199.150635      1977.361162  300.297641  5051.77677      93.280652
# std     111.303847        15.777610  172.284243    28.62083     778.407554
# min    1001.000000      1950.000000    1.000000  5001.00000     -10.000000
# 25%    1100.500000      1964.000000  152.000000  5028.00000      22.500000
# 50%    1203.000000      1977.000000  302.000000  5051.00000      30.100000
# 75%    1290.500000      1990.000000  448.500000  5077.00000      38.000000
# max    1400.000000      2005.000000  600.000000  5100.00000    9999.000000
#
#          Cijena_USD     Starost
# count    497.000000  551.000000
# mean     200.990986   47.638838
# std      905.118388   15.777610
# min        0.000000   20.000000
# 25%       63.930000   35.000000
# 50%      108.080000   48.000000
# 75%      136.030000   61.000000
# max    10000.000000   75.000000

# %%
### Zaključak: godina rođenja se čini ok, a sukladno tome i starost. Trajanje ima jednu anomalije 
### (min = -10) te (max = 9999). Cijena se čini ok u pretpostavku da imamo bespaltnih tečaja i 
### specijalitičkih koji mogu koštati više tisuća USD

# %%
polaznici_UT.isna().sum()
# Out:
# PolaznikID          0
# Godina_Rodjenja     0
# Regija             29
# Jezik_Platforme     0
# UpisID              0
# TecajID             0
# Datum_Upisa         3
# Status_Upisa        0
# Naziv_Tecaja        0
# Razina              0
# Trajanje_Sati      60
# Cijena_USD         54
# Starost             0
# dtype: int64

# %%
### Zaključak: Regija, Datum_Upisa, Trajanje_sati i Cijena_USD imaju prazne ćelije koje treba 
### nekako riješiti

# %%
polaznici_UT["Regija"].value_counts()
# Out:
# Regija
# Europa              167
# Sjeverna Amerika    125
# Azija                86
# Afrika               63
# Južna Amerika        46
# Australija           35
# Name: count, dtype: int64

# %%
### Zaključak: Regija nema krive zapise, pa nema potrebe uređivati, ali je potrebno popuniti prazne
### ćelije

# %%
polaznici_UT["Regija"].mode()
# Out:
# 0    Europa
# Name: Regija, dtype: object

# %%
polaznici_UT["Regija"] = polaznici_UT["Regija"].fillna(value="Europa")

# %%
polaznici_UT["Regija"].value_counts()
# Out:
# Regija
# Europa              196
# Sjeverna Amerika    125
# Azija                86
# Afrika               63
# Južna Amerika        46
# Australija           35
# Name: count, dtype: int64

# %%
polaznici_UT.isna().sum()
# Out:
# PolaznikID          0
# Godina_Rodjenja     0
# Regija              0
# Jezik_Platforme     0
# UpisID              0
# TecajID             0
# Datum_Upisa         3
# Status_Upisa        0
# Naziv_Tecaja        0
# Razina              0
# Trajanje_Sati      60
# Cijena_USD         54
# Starost             0
# dtype: int64

# %%
### Zaključak: Regija je sad uređena i nema više praznih ćelija

# %%
polaznici_UT
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme  UpisID  \
# 0          1377             1979            Europa      Španjolski     495
# 1          1221             1973            Europa       Francuski     168
# 2          1221             1973            Europa       Francuski     449
# 3          1221             1973            Europa       Francuski     335
# 4          1221             1973            Europa       Francuski      30
# ..          ...              ...               ...             ...     ...
# 546        1044             1952            Europa        Engleski      58
# 547        1126             1991             Azija        Engleski     112
# 548        1186             1971  Sjeverna Amerika      Španjolski     398
# 549        1035             1991  Sjeverna Amerika        Engleski     313
# 550        1035             1991  Sjeverna Amerika        Engleski     153
#
#      TecajID Datum_Upisa Status_Upisa            Naziv_Tecaja    Razina  \
# 0     5089.0  12-08-2024      Završen         Cloud Computing   Srednji
# 1     5068.0  2022-03-05      Završen   Strojno učenje osnove   Srednji
# 2     5083.0  2024-06-16      Aktivan         Cloud Computing  Napredni
# 3     5025.0  26-09-2022      Aktivan           Uvod u Python   Početni
# 4     5033.0  2023-11-11      Aktivan       Data Storytelling   Početni
# ..       ...         ...          ...                     ...       ...
# 546   5094.0  2022-12-25      Odustao        Excel za analizu   Početni
# 547   5081.0  04/24/2023      Završen  Vizualizacija podataka   početni
# 548   5001.0  03/03/2024   Na čekanju  Vizualizacija podataka   Srednji
# 549   5095.0  03/02/2024      Aktivan           Uvod u Python   Početni
# 550   5007.0  01/31/2022      Aktivan   Strojno učenje osnove   Srednji
#
#      Trajanje_Sati  Cijena_USD  Starost
# 0             19.1       20.00       46
# 1             30.6       81.00       52
# 2             22.5       61.05       52
# 3              NaN       66.03       52
# 4             30.6         NaN       52
# ..             ...         ...      ...
# 546           31.8      121.47       73
# 547           31.5      136.03       34
# 548           40.2      185.49       54
# 549           42.7      100.04       34
# 550           20.6       82.92       34
#
# [551 rows x 13 columns]

# %%
polaznici_UT["Jezik_Platforme"].value_counts()
# Out:
# Jezik_Platforme
# Engleski      292
# Španjolski     55
# Francuski      55
# Njemački       45
# Hrvatski       36
# engleski       28
# španjolski     14
# ENG             8
# hrvatski        7
# francuski       6
# ŠPA             3
# njemački        1
# HRV             1
# Name: count, dtype: int64

# %%
### Zaključak: Jezik platforme nema praznih ćelija, ali zato ima više riječi napisanih raznim stilovima

# %%
polaznici_UT["Jezik_Platforme"] = polaznici_UT["Jezik_Platforme"].str.title()

# %%
polaznici_UT["Jezik_Platforme"].value_counts()
# Out:
# Jezik_Platforme
# Engleski      320
# Španjolski     69
# Francuski      61
# Njemački       46
# Hrvatski       43
# Eng             8
# Špa             3
# Hrv             1
# Name: count, dtype: int64

# %%
### Zaključak: metodom titile() sredili smo nazive jezika, ali ostale su još neke kratice

# %%
polaznici_UT["Jezik_Platforme"] = polaznici_UT["Jezik_Platforme"].replace({
    "Eng": "Engleski",
    "Špa": "Španjolski",
    "Hrv": "Hrvatski" 
})

# %%
polaznici_UT["Jezik_Platforme"].value_counts()
# Out:
# Jezik_Platforme
# Engleski      328
# Španjolski     72
# Francuski      61
# Njemački       46
# Hrvatski       44
# Name: count, dtype: int64

# %%
### Zaključak: ispravljene su sve nepravilnosti u stringovima

# %%
polaznici_UT
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme  UpisID  \
# 0          1377             1979            Europa      Španjolski     495
# 1          1221             1973            Europa       Francuski     168
# 2          1221             1973            Europa       Francuski     449
# 3          1221             1973            Europa       Francuski     335
# 4          1221             1973            Europa       Francuski      30
# ..          ...              ...               ...             ...     ...
# 546        1044             1952            Europa        Engleski      58
# 547        1126             1991             Azija        Engleski     112
# 548        1186             1971  Sjeverna Amerika      Španjolski     398
# 549        1035             1991  Sjeverna Amerika        Engleski     313
# 550        1035             1991  Sjeverna Amerika        Engleski     153
#
#      TecajID Datum_Upisa Status_Upisa            Naziv_Tecaja    Razina  \
# 0     5089.0  12-08-2024      Završen         Cloud Computing   Srednji
# 1     5068.0  2022-03-05      Završen   Strojno učenje osnove   Srednji
# 2     5083.0  2024-06-16      Aktivan         Cloud Computing  Napredni
# 3     5025.0  26-09-2022      Aktivan           Uvod u Python   Početni
# 4     5033.0  2023-11-11      Aktivan       Data Storytelling   Početni
# ..       ...         ...          ...                     ...       ...
# 546   5094.0  2022-12-25      Odustao        Excel za analizu   Početni
# 547   5081.0  04/24/2023      Završen  Vizualizacija podataka   početni
# 548   5001.0  03/03/2024   Na čekanju  Vizualizacija podataka   Srednji
# 549   5095.0  03/02/2024      Aktivan           Uvod u Python   Početni
# 550   5007.0  01/31/2022      Aktivan   Strojno učenje osnove   Srednji
#
#      Trajanje_Sati  Cijena_USD  Starost
# 0             19.1       20.00       46
# 1             30.6       81.00       52
# 2             22.5       61.05       52
# 3              NaN       66.03       52
# 4             30.6         NaN       52
# ..             ...         ...      ...
# 546           31.8      121.47       73
# 547           31.5      136.03       34
# 548           40.2      185.49       54
# 549           42.7      100.04       34
# 550           20.6       82.92       34
#
# [551 rows x 13 columns]

# %%
polaznici_UT["Datum_Upisa"].value_counts()
# Out:
# Datum_Upisa
# Unknown Date    4
# 12/03/2024      4
# 2023-11-04      3
# 08/18/2024      3
# 05/02/2023      3
#                ..
# 11/04/2024      1
# 04/07/2023      1
# 22-08-2022      1
# 2023-06-09      1
# 16-03-2022      1
# Name: count, Length: 478, dtype: int64

# %%
### Zaključak: Datum upisa ima 3 NaN value, 4 Unknown date te više različitih formata zapisa datuma....

# %%
polaznici_UT[pd.isna(polaznici_UT["Datum_Upisa"])]
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme  UpisID  \
# 150        1302             1972  Sjeverna Amerika        Engleski      44
# 165        1199             1960  Sjeverna Amerika       Francuski     307
# 463        1078             1953            Europa      Španjolski      90
#
#      TecajID Datum_Upisa Status_Upisa                Naziv_Tecaja   Razina  \
# 150   5078.0         NaN      Aktivan      Vizualizacija podataka  početni
# 165   5005.0         NaN      Aktivan  Statistika za Data Science  Početni
# 463   5009.0         NaN      Aktivan             Cloud Computing  Srednji
#
#      Trajanje_Sati  Cijena_USD  Starost
# 150            NaN      112.62       53
# 165            NaN        0.01       65
# 463           35.2      104.36       72

# %%
polaznici_UT["Datum_Upisa"] = polaznici_UT["Datum_Upisa"].replace("Unknown Date", pd.NaT)

# %%
polaznici_UT[pd.isna(polaznici_UT["Datum_Upisa"])]
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme  UpisID  \
# 143        1124             1982  Sjeverna Amerika        Engleski      75
# 150        1302             1972  Sjeverna Amerika        Engleski      44
# 165        1199             1960  Sjeverna Amerika       Francuski     307
# 272        1320             2004  Sjeverna Amerika        Hrvatski     416
# 307        1049             1958            Europa        Engleski     155
# 463        1078             1953            Europa      Španjolski      90
# 497        1034             1976            Afrika        Engleski     156
#
#      TecajID Datum_Upisa Status_Upisa                Naziv_Tecaja   Razina  \
# 143   5070.0         NaT      Aktivan                Napredni SQL  Srednji
# 150   5078.0         NaN      Aktivan      Vizualizacija podataka  početni
# 165   5005.0         NaN      Aktivan  Statistika za Data Science  Početni
# 272   5024.0         NaT      Odustao             Cloud Computing  Srednji
# 307   5026.0         NaT      Aktivan      Vizualizacija podataka  Početni
# 463   5009.0         NaN      Aktivan             Cloud Computing  Srednji
# 497   5037.0         NaT      Aktivan            Excel za analizu  Srednji
#
#      Trajanje_Sati  Cijena_USD  Starost
# 143           31.1       92.61       43
# 150            NaN      112.62       53
# 165            NaN        0.01       65
# 272           26.9      133.22       21
# 307           19.7       58.79       67
# 463           35.2      104.36       72
# 497            NaN        0.00       49

# %%
polaznici_UT['Datum_Upisa'] = polaznici_UT['Datum_Upisa'].ffill()

# %%
polaznici_UT[pd.isna(polaznici_UT["Datum_Upisa"])]
# Out:
# Empty DataFrame
# Columns: [PolaznikID, Godina_Rodjenja, Regija, Jezik_Platforme, UpisID, TecajID, Datum_Upisa, Status_Upisa, Naziv_Tecaja, Razina, Trajanje_Sati, Cijena_USD, Starost]
# Index: []

# %%
### Zaključak: Datum upisa više nema praznih ćelija. Ostaje za srediti mješovoti format datuma.

# %%
polaznici_UT["Datum_Upisa"]
# Out:
# 0      12-08-2024
# 1      2022-03-05
# 2      2024-06-16
# 3      26-09-2022
# 4      2023-11-11
#           ...
# 546    2022-12-25
# 547    04/24/2023
# 548    03/03/2024
# 549    03/02/2024
# 550    01/31/2022
# Name: Datum_Upisa, Length: 551, dtype: object
