# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
polaznici = pd.read_csv("df_polaznici.csv")

# %%
upisi = pd.read_csv("df_upisi.csv")

# %%
tecajevi = pd.read_csv("df_tecajevi.csv")

# %%
polaznici
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme
# 0          1377             1979            Europa      Španjolski
# 1          1221             1973            Europa       Francuski
# 2          1100             2002            Europa      Španjolski
# 3          1218             2000               NaN       Francuski
# 4          1057             1975     Južna Amerika        Engleski
# ..          ...              ...               ...             ...
# 405        1044             1952               NaN        Engleski
# 406        1126             1991             Azija        Engleski
# 407        1245             2003  Sjeverna Amerika        Engleski
# 408        1186             1971  Sjeverna Amerika      Španjolski
# 409        1035             1991  Sjeverna Amerika        Engleski
#
# [410 rows x 4 columns]

# %%
tecajevi
# Out:
#     TecajID           Naziv_Tecaja    Razina  Trajanje_Sati  Cijena_USD
# 0      5015  Strojno učenje osnove   Srednji           35.6       88.24
# 1      5013      Data Storytelling   Srednji           46.0      182.10
# 2      5082  Strojno učenje osnove   Srednji           26.0       70.64
# 3      5043           Napredni SQL   srednji           31.8      126.97
# 4      5064  Strojno učenje osnove  napredni          -10.0       20.00
# ..      ...                    ...       ...            ...         ...
# 95     5050          Uvod u Python   srednji           34.9      146.22
# 96     5021        Cloud Computing   Srednji           42.3    10000.00
# 97     5086      Data Storytelling   Početni           28.3      180.95
# 98     5085        Cloud Computing   Početni            NaN      193.78
# 99     5054          Uvod u Python   Srednji           26.3       96.36
#
# [100 rows x 5 columns]

# %%
upisi
# Out:
#      UpisID  PolaznikID  TecajID Datum_Upisa Status_Upisa
# 0        10      1156.0   5095.0  07/20/2023      Aktivan
# 1        41      1400.0   6202.0  11-10-2023      Završen
# 2       456      1065.0   5091.0  07/10/2024   Na čekanju
# 3       404      1314.0   5033.0  2023-11-12      Završen
# 4       592      1272.0   5090.0  24-02-2022      Aktivan
# ..      ...         ...      ...         ...          ...
# 610     424      1048.0   5047.0  06/13/2024      Aktivan
# 611     533      1119.0   5012.0  09/25/2022      Aktivan
# 612     224      1149.0   5044.0  27-10-2023      Aktivan
# 613      70      1088.0   5084.0  18-05-2024      Aktivan
# 614      16      1064.0      NaN  03-07-2024      Aktivan
#
# [615 rows x 5 columns]

# %%
polaznici_upisi = pd.merge (polaznici, upisi, on ="PolaznikID", how ="inner")

# %%
polaznici_upisi
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme  UpisID  \
# 0          1377             1979            Europa      Španjolski     495
# 1          1221             1973            Europa       Francuski     168
# 2          1221             1973            Europa       Francuski     449
# 3          1221             1973            Europa       Francuski     335
# 4          1221             1973            Europa       Francuski      30
# ..          ...              ...               ...             ...     ...
# 586        1126             1991             Azija        Engleski     112
# 587        1245             2003  Sjeverna Amerika        Engleski     575
# 588        1186             1971  Sjeverna Amerika      Španjolski     398
# 589        1035             1991  Sjeverna Amerika        Engleski     313
# 590        1035             1991  Sjeverna Amerika        Engleski     153
#
#      TecajID  Datum_Upisa Status_Upisa
# 0     5089.0   12-08-2024      Završen
# 1     5068.0   2022-03-05      Završen
# 2     5083.0   2024-06-16      Aktivan
# 3     5025.0   26-09-2022      Aktivan
# 4     5033.0   2023-11-11      Aktivan
# ..       ...          ...          ...
# 586   5081.0   04/24/2023      Završen
# 587   6037.0  2025-Feb-30      Aktivan
# 588   5001.0   03/03/2024   Na čekanju
# 589   5095.0   03/02/2024      Aktivan
# 590   5007.0   01/31/2022      Aktivan
#
# [591 rows x 8 columns]

# %%
polaznici_upisi_tecajevi = pd.merge (polaznici_upisi, tecajevi, on ="TecajID", how ="inner")

# %%
polaznici_upisi_tecajevi
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme  UpisID  \
# 0          1377             1979            Europa      Španjolski     495
# 1          1221             1973            Europa       Francuski     168
# 2          1221             1973            Europa       Francuski     449
# 3          1221             1973            Europa       Francuski     335
# 4          1221             1973            Europa       Francuski      30
# ..          ...              ...               ...             ...     ...
# 546        1044             1952               NaN        Engleski      58
# 547        1126             1991             Azija        Engleski     112
# 548        1186             1971  Sjeverna Amerika      Španjolski     398
# 549        1035             1991  Sjeverna Amerika        Engleski     313
# 550        1035             1991  Sjeverna Amerika        Engleski     153
#
#      TecajID Datum_Upisa Status_Upisa            Naziv_Tecaja    Razina  \
# 0     5089.0  12-08-2024      Završen         Cloud Computing   Srednji
# 1     5068.0  2022-03-05      Završen   Strojno učenje osnove   Srednji
# 2     5083.0  2024-06-16      Aktivan         Cloud Computing  Napredni
# 3     5025.0  26-09-2022      Aktivan           Uvod u Python   Početni
# 4     5033.0  2023-11-11      Aktivan       Data Storytelling   Početni
# ..       ...         ...          ...                     ...       ...
# 546   5094.0  2022-12-25      Odustao        Excel za analizu   Početni
# 547   5081.0  04/24/2023      Završen  Vizualizacija podataka   početni
# 548   5001.0  03/03/2024   Na čekanju  Vizualizacija podataka   Srednji
# 549   5095.0  03/02/2024      Aktivan           Uvod u Python   Početni
# 550   5007.0  01/31/2022      Aktivan   Strojno učenje osnove   Srednji
#
#      Trajanje_Sati  Cijena_USD
# 0             19.1       20.00
# 1             30.6       81.00
# 2             22.5       61.05
# 3              NaN       66.03
# 4             30.6         NaN
# ..             ...         ...
# 546           31.8      121.47
# 547           31.5      136.03
# 548           40.2      185.49
# 549           42.7      100.04
# 550           20.6       82.92
#
# [551 rows x 12 columns]

# %%
polaznici_upisi_tecajevi ['starost'] = 2025 - polaznici_upisi_tecajevi ['Godina_Rodjenja']

# %%
polaznici_upisi_tecajevi
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme  UpisID  \
# 0          1377             1979            Europa      Španjolski     495
# 1          1221             1973            Europa       Francuski     168
# 2          1221             1973            Europa       Francuski     449
# 3          1221             1973            Europa       Francuski     335
# 4          1221             1973            Europa       Francuski      30
# ..          ...              ...               ...             ...     ...
# 546        1044             1952               NaN        Engleski      58
# 547        1126             1991             Azija        Engleski     112
# 548        1186             1971  Sjeverna Amerika      Španjolski     398
# 549        1035             1991  Sjeverna Amerika        Engleski     313
# 550        1035             1991  Sjeverna Amerika        Engleski     153
#
#      TecajID Datum_Upisa Status_Upisa            Naziv_Tecaja    Razina  \
# 0     5089.0  12-08-2024      Završen         Cloud Computing   Srednji
# 1     5068.0  2022-03-05      Završen   Strojno učenje osnove   Srednji
# 2     5083.0  2024-06-16      Aktivan         Cloud Computing  Napredni
# 3     5025.0  26-09-2022      Aktivan           Uvod u Python   Početni
# 4     5033.0  2023-11-11      Aktivan       Data Storytelling   Početni
# ..       ...         ...          ...                     ...       ...
# 546   5094.0  2022-12-25      Odustao        Excel za analizu   Početni
# 547   5081.0  04/24/2023      Završen  Vizualizacija podataka   početni
# 548   5001.0  03/03/2024   Na čekanju  Vizualizacija podataka   Srednji
# 549   5095.0  03/02/2024      Aktivan           Uvod u Python   Početni
# 550   5007.0  01/31/2022      Aktivan   Strojno učenje osnove   Srednji
#
#      Trajanje_Sati  Cijena_USD  starost
# 0             19.1       20.00       46
# 1             30.6       81.00       52
# 2             22.5       61.05       52
# 3              NaN       66.03       52
# 4             30.6         NaN       52
# ..             ...         ...      ...
# 546           31.8      121.47       73
# 547           31.5      136.03       34
# 548           40.2      185.49       54
# 549           42.7      100.04       34
# 550           20.6       82.92       34
#
# [551 rows x 13 columns]

# %%
polaznici_upisi_tecajevi.describe()
# Out:
#         PolaznikID  Godina_Rodjenja      UpisID     TecajID  Trajanje_Sati  \
# count   551.000000       551.000000  551.000000   551.00000     491.000000
# mean   1199.150635      1977.361162  300.297641  5051.77677      93.280652
# std     111.303847        15.777610  172.284243    28.62083     778.407554
# min    1001.000000      1950.000000    1.000000  5001.00000     -10.000000
# 25%    1100.500000      1964.000000  152.000000  5028.00000      22.500000
# 50%    1203.000000      1977.000000  302.000000  5051.00000      30.100000
# 75%    1290.500000      1990.000000  448.500000  5077.00000      38.000000
# max    1400.000000      2005.000000  600.000000  5100.00000    9999.000000
#
#          Cijena_USD     starost
# count    497.000000  551.000000
# mean     200.990986   47.638838
# std      905.118388   15.777610
# min        0.000000   20.000000
# 25%       63.930000   35.000000
# 50%      108.080000   48.000000
# 75%      136.030000   61.000000
# max    10000.000000   75.000000

# %%
sns.boxplot (x = polaznici_upisi_tecajevi ["Cijena_USD"])
# Out:
# <Axes: xlabel='Cijena_USD'>

# %%
sns.boxplot (x = polaznici_upisi_tecajevi ["Trajanje_Sati"])
# Out:
# <Axes: xlabel='Trajanje_Sati'>

# %%
sns.boxplot (x = polaznici_upisi_tecajevi ["Godina_Rodjenja"])
# Out:
# <Axes: xlabel='Godina_Rodjenja'>

# %%
polaznici_upisi_tecajevi.loc[polaznici_upisi_tecajevi['Cijena_USD']>5000.0]
# Out:
#      PolaznikID  Godina_Rodjenja      Regija Jezik_Platforme  UpisID  TecajID  \
# 106        1230             1998  Australija        Engleski     392   5021.0
# 335        1095             1970      Europa      španjolski     355   5021.0
# 369        1356             1985       Azija        Engleski     428   5021.0
# 473        1365             1957      Europa        Engleski     247   5021.0
#
#     Datum_Upisa Status_Upisa     Naziv_Tecaja   Razina  Trajanje_Sati  \
# 106  25-06-2022      Odustao  Cloud Computing  Srednji           42.3
# 335  30-07-2022      Aktivan  Cloud Computing  Srednji           42.3
# 369  10/15/2024      Završen  Cloud Computing  Srednji           42.3
# 473  26-12-2024      Aktivan  Cloud Computing  Srednji           42.3
#
#      Cijena_USD  starost
# 106     10000.0       27
# 335     10000.0       55
# 369     10000.0       40
# 473     10000.0       68

# %%
polaznici_upisi_tecajevi.loc[polaznici_upisi_tecajevi['Cijena_USD']>1000.0]
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme  UpisID  \
# 106        1230             1998        Australija        Engleski     392
# 139        1212             1955  Sjeverna Amerika       Francuski     473
# 234        1196             1993  Sjeverna Amerika       Francuski     284
# 335        1095             1970            Europa      španjolski     355
# 354        1050             1988  Sjeverna Amerika        Engleski     286
# 369        1356             1985             Azija        Engleski     428
# 432        1212             1955  Sjeverna Amerika       Francuski     473
# 473        1365             1957            Europa        Engleski     247
# 478        1174             1986  Sjeverna Amerika        Hrvatski      82
#
#      TecajID Datum_Upisa Status_Upisa                Naziv_Tecaja   Razina  \
# 106   5021.0  25-06-2022      Odustao             Cloud Computing  Srednji
# 139   5018.0  20-12-2022      Aktivan  Statistika za Data Science  Srednji
# 234   5018.0  08/18/2024      Završen  Statistika za Data Science  Srednji
# 335   5021.0  30-07-2022      Aktivan             Cloud Computing  Srednji
# 354   5018.0  04/26/2022      Aktivan  Statistika za Data Science  Srednji
# 369   5021.0  10/15/2024      Završen             Cloud Computing  Srednji
# 432   5018.0  20-12-2022      Aktivan  Statistika za Data Science  Srednji
# 473   5021.0  26-12-2024      Aktivan             Cloud Computing  Srednji
# 478   5018.0  10/14/2024      Aktivan  Statistika za Data Science  Srednji
#
#      Trajanje_Sati  Cijena_USD  starost
# 106           42.3     10000.0       27
# 139           39.5      2000.0       70
# 234           39.5      2000.0       32
# 335           42.3     10000.0       55
# 354           39.5      2000.0       37
# 369           42.3     10000.0       40
# 432           39.5      2000.0       70
# 473           42.3     10000.0       68
# 478           39.5      2000.0       39

# %%
polaznici_upisi_tecajevi.loc[polaznici_upisi_tecajevi['Trajanje_Sati']>100]
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme  UpisID  \
# 41         1217             1982            Europa        Engleski     386
# 120        1001             1988            Afrika             ŠPA     526
# 193        1055             1999            Europa             ŠPA     522
# 284        1120             1966  Sjeverna Amerika       francuski     466
# 444        1092             1963     Južna Amerika        Engleski      98
# 523        1180             1978     Južna Amerika        Engleski     251
#
#      TecajID Datum_Upisa Status_Upisa     Naziv_Tecaja    Razina  \
# 41    5097.0  21-11-2024      Aktivan  Cloud Computing  BEGINNER
# 120   5097.0  2022-05-03      Završen  Cloud Computing  BEGINNER
# 193   5011.0  09/11/2023      Aktivan     Napredni SQL   Početni
# 284   5011.0  08/30/2022      Aktivan     Napredni SQL   Početni
# 444   5011.0  12/03/2022   Na čekanju     Napredni SQL   Početni
# 523   5097.0  03/28/2022      Aktivan  Cloud Computing  BEGINNER
#
#      Trajanje_Sati  Cijena_USD  starost
# 41           500.0      183.58       43
# 120          500.0      183.58       37
# 193         9999.0       83.07       26
# 284         9999.0       83.07       59
# 444         9999.0       83.07       62
# 523          500.0      183.58       47

# %%
sns.boxplot (x = polaznici_upisi_tecajevi ["Trajanje_Sati"])
# Out:
# <Axes: xlabel='Trajanje_Sati'>

# %%
sns.boxplot (x = polaznici_upisi_tecajevi ["Godina_Rodjenja"])
# Out:
# <Axes: xlabel='Godina_Rodjenja'>

# %%
sns.scatterplot (data = polaznici_upisi_tecajevi, x = "Cijena_USD", y = "Trajanje_Sati")
# Out:
# <Axes: xlabel='Cijena_USD', ylabel='Trajanje_Sati'>

# %%
polaznici_upisi_tecajevi ['Datum_Upisa'] = polaznici_upisi_tecajevi['Datum_Upisa'].replace('Unknown Date', np.nan)

# %%
polaznici_upisi_tecajevi['Datum_Upisa'] = polaznici_upisi_tecajevi['Datum_Upisa'].fillna(method ='ffill')

# %%
polaznici_upisi_tecajevi
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme  UpisID  \
# 0          1377             1979            Europa      Španjolski     495
# 1          1221             1973            Europa       Francuski     168
# 2          1221             1973            Europa       Francuski     449
# 3          1221             1973            Europa       Francuski     335
# 4          1221             1973            Europa       Francuski      30
# ..          ...              ...               ...             ...     ...
# 546        1044             1952               NaN        Engleski      58
# 547        1126             1991             Azija        Engleski     112
# 548        1186             1971  Sjeverna Amerika      Španjolski     398
# 549        1035             1991  Sjeverna Amerika        Engleski     313
# 550        1035             1991  Sjeverna Amerika        Engleski     153
#
#      TecajID Datum_Upisa Status_Upisa            Naziv_Tecaja    Razina  \
# 0     5089.0  12-08-2024      Završen         Cloud Computing   Srednji
# 1     5068.0  2022-03-05      Završen   Strojno učenje osnove   Srednji
# 2     5083.0  2024-06-16      Aktivan         Cloud Computing  Napredni
# 3     5025.0  26-09-2022      Aktivan           Uvod u Python   Početni
# 4     5033.0  2023-11-11      Aktivan       Data Storytelling   Početni
# ..       ...         ...          ...                     ...       ...
# 546   5094.0  2022-12-25      Odustao        Excel za analizu   Početni
# 547   5081.0  04/24/2023      Završen  Vizualizacija podataka   početni
# 548   5001.0  03/03/2024   Na čekanju  Vizualizacija podataka   Srednji
# 549   5095.0  03/02/2024      Aktivan           Uvod u Python   Početni
# 550   5007.0  01/31/2022      Aktivan   Strojno učenje osnove   Srednji
#
#      Trajanje_Sati  Cijena_USD  starost
# 0             19.1       20.00       46
# 1             30.6       81.00       52
# 2             22.5       61.05       52
# 3              NaN       66.03       52
# 4             30.6         NaN       52
# ..             ...         ...      ...
# 546           31.8      121.47       73
# 547           31.5      136.03       34
# 548           40.2      185.49       54
# 549           42.7      100.04       34
# 550           20.6       82.92       34
#
# [551 rows x 13 columns]

# %%
polaznici_upisi_tecajevi.loc[polaznici_upisi_tecajevi['Trajanje_Sati']>100]
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme  UpisID  \
# 41         1217             1982            Europa        Engleski     386
# 120        1001             1988            Afrika             ŠPA     526
# 193        1055             1999            Europa             ŠPA     522
# 284        1120             1966  Sjeverna Amerika       francuski     466
# 444        1092             1963     Južna Amerika        Engleski      98
# 523        1180             1978     Južna Amerika        Engleski     251
#
#      TecajID Datum_Upisa Status_Upisa     Naziv_Tecaja    Razina  \
# 41    5097.0  21-11-2024      Aktivan  Cloud Computing  BEGINNER
# 120   5097.0  2022-05-03      Završen  Cloud Computing  BEGINNER
# 193   5011.0  09/11/2023      Aktivan     Napredni SQL   Početni
# 284   5011.0  08/30/2022      Aktivan     Napredni SQL   Početni
# 444   5011.0  12/03/2022   Na čekanju     Napredni SQL   Početni
# 523   5097.0  03/28/2022      Aktivan  Cloud Computing  BEGINNER
#
#      Trajanje_Sati  Cijena_USD  starost
# 41           500.0      183.58       43
# 120          500.0      183.58       37
# 193         9999.0       83.07       26
# 284         9999.0       83.07       59
# 444         9999.0       83.07       62
# 523          500.0      183.58       47

# %%
sns.scatterplot (data = polaznici_upisi_tecajevi, x = "Cijena_USD", y = "Trajanje_Sati")
# Out:
# <Axes: xlabel='Cijena_USD', ylabel='Trajanje_Sati'>

# %%
polaznici_upisi_tecajevi.describe()
# Out:
#         PolaznikID  Godina_Rodjenja      UpisID     TecajID  Trajanje_Sati  \
# count   551.000000       551.000000  551.000000   551.00000     491.000000
# mean   1199.150635      1977.361162  300.297641  5051.77677      93.280652
# std     111.303847        15.777610  172.284243    28.62083     778.407554
# min    1001.000000      1950.000000    1.000000  5001.00000     -10.000000
# 25%    1100.500000      1964.000000  152.000000  5028.00000      22.500000
# 50%    1203.000000      1977.000000  302.000000  5051.00000      30.100000
# 75%    1290.500000      1990.000000  448.500000  5077.00000      38.000000
# max    1400.000000      2005.000000  600.000000  5100.00000    9999.000000
#
#          Cijena_USD     starost
# count    497.000000  551.000000
# mean     200.990986   47.638838
# std      905.118388   15.777610
# min        0.000000   20.000000
# 25%       63.930000   35.000000
# 50%      108.080000   48.000000
# 75%      136.030000   61.000000
# max    10000.000000   75.000000

# %%
polaznici_upisi_tecajevi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551 entries, 0 to 550
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PolaznikID       551 non-null    int64
#  1   Godina_Rodjenja  551 non-null    int64
#  2   Regija           522 non-null    object
#  3   Jezik_Platforme  551 non-null    object
#  4   UpisID           551 non-null    int64
#  5   TecajID          551 non-null    float64
#  6   Datum_Upisa      551 non-null    object
#  7   Status_Upisa     551 non-null    object
#  8   Naziv_Tecaja     551 non-null    object
#  9   Razina           551 non-null    object
#  10  Trajanje_Sati    491 non-null    float64
#  11  Cijena_USD       497 non-null    float64
#  12  starost          551 non-null    int64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 56.1+ KB

# %%
polaznici_upisi_tecajevi.isna().sum()
# Out:
# PolaznikID          0
# Godina_Rodjenja     0
# Regija             29
# Jezik_Platforme     0
# UpisID              0
# TecajID             0
# Datum_Upisa         0
# Status_Upisa        0
# Naziv_Tecaja        0
# Razina              0
# Trajanje_Sati      60
# Cijena_USD         54
# starost             0
# dtype: int64

# %%
# medijanom punimo cijenu (nije outlier) za Cijena_USD
median_cijena = polaznici_upisi_tecajevi["Cijena_USD"].median()

# %%
polaznici_upisi_tecajevi["Cijena_USD"] = polaznici_upisi_tecajevi["Cijena_USD"].fillna(value=median_cijena)

# %%
polaznici_upisi_tecajevi["Jezik_Platforme"]=polaznici_upisi_tecajevi["Jezik_Platforme"].str.title()

# %%
polaznici_upisi_tecajevi["Jezik_Platforme"].replace({"Eng": "Engleski"}, inplace=True)

# %%
polaznici_upisi_tecajevi ["Jezik_Platforme"].replace({"Špa": "Španjolski"}, inplace=True)

# %%
polaznici_upisi_tecajevi["Jezik_Platforme"].replace({"Hrv": "Hrvatski"}, inplace=True)

# %%
polaznici_upisi_tecajevi["Jezik_Platforme"].replace({"Španjolski": "Spanjolski"}, inplace=True)

# %%
polaznici_upisi_tecajevi["Jezik_Platforme"].replace({"Njemački": "Njemacki"}, inplace=True)

# %%
polaznici_upisi_tecajevi["Jezik_Platforme"].value_counts()
# Out:
# Jezik_Platforme
# Engleski      328
# Spanjolski     72
# Francuski      61
# Njemacki       46
# Hrvatski       44
# Name: count, dtype: int64

# %%
polaznici_upisi_tecajevi.loc[polaznici_upisi_tecajevi['Trajanje_Sati']<0]
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme  UpisID  \
# 45         1190             1994            Europa       Francuski     594
# 192        1142             1993  Sjeverna Amerika        Engleski     339
# 268        1032             1974     Južna Amerika        Engleski     391
# 317        1101             1973             Azija        Engleski     586
# 341        1069             1966     Južna Amerika        Engleski     306
# 356        1287             1969             Azija        Engleski     255
# 481        1381             2000            Europa      Spanjolski     222
#
#      TecajID Datum_Upisa Status_Upisa           Naziv_Tecaja    Razina  \
# 45    5064.0  12-04-2023      Završen  Strojno učenje osnove  napredni
# 192   5064.0  2024-06-15      Završen  Strojno učenje osnove  napredni
# 268   5064.0  2024-05-03      Aktivan  Strojno učenje osnove  napredni
# 317   5064.0  30-09-2024      Završen  Strojno učenje osnove  napredni
# 341   5064.0  11/22/2022      Aktivan  Strojno učenje osnove  napredni
# 356   5064.0  08-04-2024      Aktivan  Strojno učenje osnove  napredni
# 481   5064.0  11/19/2022      Završen  Strojno učenje osnove  napredni
#
#      Trajanje_Sati  Cijena_USD  starost
# 45           -10.0        20.0       31
# 192          -10.0        20.0       32
# 268          -10.0        20.0       51
# 317          -10.0        20.0       52
# 341          -10.0        20.0       59
# 356          -10.0        20.0       56
# 481          -10.0        20.0       25

# %%
# mijenjanje negativnih vrijednosti (trajanje tecaja) u apsolutnu vrijednost
polaznici_upisi_tecajevi['Trajanje_Sati'] = polaznici_upisi_tecajevi['Trajanje_Sati'].abs()

# %%
polaznici_upisi_tecajevi.describe()
# Out:
#         PolaznikID  Godina_Rodjenja      UpisID     TecajID  Trajanje_Sati  \
# count   551.000000       551.000000  551.000000   551.00000     491.000000
# mean   1199.150635      1977.361162  300.297641  5051.77677      93.565784
# std     111.303847        15.777610  172.284243    28.62083     778.373262
# min    1001.000000      1950.000000    1.000000  5001.00000       0.000000
# 25%    1100.500000      1964.000000  152.000000  5028.00000      22.500000
# 50%    1203.000000      1977.000000  302.000000  5051.00000      30.100000
# 75%    1290.500000      1990.000000  448.500000  5077.00000      38.000000
# max    1400.000000      2005.000000  600.000000  5100.00000    9999.000000
#
#          Cijena_USD     starost
# count    551.000000  551.000000
# mean     191.885372   47.638838
# std      859.982197   15.777610
# min        0.000000   20.000000
# 25%       70.640000   35.000000
# 50%      108.080000   48.000000
# 75%      134.110000   61.000000
# max    10000.000000   75.000000

# %%
polaznici_upisi_tecajevi['Trajanje_Sati'].median()
# Out:
# 30.4

# %%
polaznici_upisi_tecajevi['Trajanje_Sati'] = polaznici_upisi_tecajevi['Trajanje_Sati'].replace(0.000000, np.nan)

# %%
polaznici_upisi_tecajevi['Trajanje_Sati'] = polaznici_upisi_tecajevi['Trajanje_Sati'].fillna(30.4)

# %%
polaznici_upisi_tecajevi.describe()
# Out:
#         PolaznikID  Godina_Rodjenja      UpisID     TecajID  Trajanje_Sati  \
# count   551.000000       551.000000  551.000000   551.00000     551.000000
# mean   1199.150635      1977.361162  300.297641  5051.77677      87.073684
# std     111.303847        15.777610  172.284243    28.62083     734.916986
# min    1001.000000      1950.000000    1.000000  5001.00000       1.000000
# 25%    1100.500000      1964.000000  152.000000  5028.00000      24.300000
# 50%    1203.000000      1977.000000  302.000000  5051.00000      30.400000
# 75%    1290.500000      1990.000000  448.500000  5077.00000      37.500000
# max    1400.000000      2005.000000  600.000000  5100.00000    9999.000000
#
#          Cijena_USD     starost
# count    551.000000  551.000000
# mean     191.885372   47.638838
# std      859.982197   15.777610
# min        0.000000   20.000000
# 25%       70.640000   35.000000
# 50%      108.080000   48.000000
# 75%      134.110000   61.000000
# max    10000.000000   75.000000

# %%
polaznici_upisi_tecajevi.isna().sum()
# Out:
# PolaznikID          0
# Godina_Rodjenja     0
# Regija             29
# Jezik_Platforme     0
# UpisID              0
# TecajID             0
# Datum_Upisa         0
# Status_Upisa        0
# Naziv_Tecaja        0
# Razina              0
# Trajanje_Sati       0
# Cijena_USD          0
# starost             0
# dtype: int64

# %%
polaznici_upisi_tecajevi["Regija"].mode()
# Out:
# 0    Europa
# Name: Regija, dtype: object

# %%
polaznici_upisi_tecajevi["Regija"] = polaznici_upisi_tecajevi["Regija"].fillna(value="Europa")

# %%
sns.boxplot (x = polaznici_upisi_tecajevi2["TecajID"])
# Out:
# <Axes: xlabel='TecajID'>

# %%
polaznici_upisi_tecajevi.isna().sum()
# Out:
# PolaznikID         0
# Godina_Rodjenja    0
# Regija             0
# Jezik_Platforme    0
# UpisID             0
# TecajID            0
# Datum_Upisa        0
# Status_Upisa       0
# Naziv_Tecaja       0
# Razina             0
# Trajanje_Sati      0
# Cijena_USD         0
# starost            0
# dtype: int64

# %%
polaznici_upisi_tecajevi[polaznici_upisi_tecajevi.duplicated(subset=['PolaznikID', 'TecajID'], keep=False)]
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme  UpisID  \
# 13         1280             1952            Europa        Engleski     170
# 14         1280             1952            Europa        Engleski     170
# 16         1246             1972            Afrika        Engleski     297
# 17         1151             1963        Australija        Engleski     166
# 18         1151             1963        Australija        Engleski     166
# ..          ...              ...               ...             ...     ...
# 492        1027             1970  Sjeverna Amerika        Engleski     100
# 495        1272             1960             Azija        Engleski     592
# 496        1272             1960             Azija        Engleski      23
# 535        1207             2001        Australija        Njemacki     338
# 536        1207             2001        Australija        Njemacki     178
#
#      TecajID Datum_Upisa Status_Upisa            Naziv_Tecaja   Razina  \
# 13    5038.0  23-05-2024      Aktivan         Cloud Computing  Srednji
# 14    5038.0  23-05-2024      Aktivan         Cloud Computing  Srednji
# 16    5049.0  01-09-2024      Završen           Uvod u Python  Početni
# 17    5098.0  12/03/2024      Završen   Strojno učenje osnove  Srednji
# 18    5098.0  12/03/2024      Završen   Strojno učenje osnove  Srednji
# ..       ...         ...          ...                     ...      ...
# 492   5057.0  2023-11-25      Aktivan        Excel za analizu  Početni
# 495   5090.0  24-02-2022      Aktivan  Vizualizacija podataka  početni
# 496   5023.0  2024-04-21      Završen   Strojno učenje osnove  Srednji
# 535   5038.0  06-12-2022      Aktivan         Cloud Computing  Srednji
# 536   5048.0  18-07-2024      Aktivan         Cloud Computing  Srednji
#
#      Trajanje_Sati  Cijena_USD  starost
# 13            40.8      165.02       73
# 14            40.8      165.02       73
# 16            29.3      126.87       53
# 17            40.1      108.08       62
# 18            40.1      108.08       62
# ..             ...         ...      ...
# 492           30.4      106.91       55
# 495           37.6       77.63       65
# 496           40.0       68.33       65
# 535           40.8      165.02       24
# 536           21.0      133.62       24
#
# [66 rows x 13 columns]

# %%
duplikati = polaznici_upisi_tecajevi.duplicated()

# %%
polaznici_upisi_tecajevi['duplikati']=duplikati

# %%
polaznici_upisi_tecajevi.loc[polaznici_upisi_tecajevi['duplikati']==True]
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme  UpisID  \
# 14         1280             1952            Europa        Engleski     170
# 18         1151             1963        Australija        Engleski     166
# 35         1151             1963        Australija        Engleski     166
# 36         1151             1963        Australija        Engleski     166
# 102        1223             2003  Sjeverna Amerika        Engleski     150
# 123        1011             1960            Europa        Hrvatski     354
# 216        1116             1957  Sjeverna Amerika      Spanjolski     185
# 223        1391             1996  Sjeverna Amerika        Engleski     434
# 319        1239             2005        Australija        Engleski     103
# 331        1095             1970            Europa      Spanjolski     515
# 367        1220             1993            Europa        Engleski     323
# 372        1352             2003            Europa        Engleski     208
# 380        1233             1988            Europa        Engleski      59
# 381        1233             1988            Europa        Engleski     147
# 382        1233             1988            Europa        Engleski     374
# 385        1152             1952             Azija        Engleski     408
# 388        1329             1973            Afrika        Engleski      17
# 415        1246             1972            Afrika        Engleski     297
# 432        1212             1955  Sjeverna Amerika       Francuski     473
# 433        1212             1955  Sjeverna Amerika       Francuski     496
# 434        1212             1955  Sjeverna Amerika       Francuski     219
# 461        1176             1988            Europa        Engleski     454
# 462        1176             1988            Europa        Engleski     501
# 468        1289             1956            Europa        Engleski     380
# 469        1289             1956            Europa        Engleski      15
# 492        1027             1970  Sjeverna Amerika        Engleski     100
# 495        1272             1960             Azija        Engleski     592
# 496        1272             1960             Azija        Engleski      23
# 535        1207             2001        Australija        Njemacki     338
# 536        1207             2001        Australija        Njemacki     178
#
#      TecajID Datum_Upisa Status_Upisa                Naziv_Tecaja    Razina  \
# 14    5038.0  23-05-2024      Aktivan             Cloud Computing   Srednji
# 18    5098.0  12/03/2024      Završen       Strojno učenje osnove   Srednji
# 35    5098.0  12/03/2024      Završen       Strojno učenje osnove   Srednji
# 36    5098.0  12/03/2024      Završen       Strojno učenje osnove   Srednji
# 102   5029.0  2023-05-29      Odustao  Statistika za Data Science   Srednji
# 123   5008.0  09/11/2024      Aktivan             Cloud Computing   Početni
# 216   5085.0  01-05-2024      Aktivan             Cloud Computing   Početni
# 223   5069.0  08/25/2023      Aktivan               Uvod u Python   Početni
# 319   5051.0  24-03-2024      Aktivan                Napredni SQL   Početni
# 331   5004.0  2022-03-26      Završen  Statistika za Data Science   srednji
# 367   5077.0  2024-12-14      Aktivan       Strojno učenje osnove  Napredni
# 372   5015.0  25-07-2023      Završen       Strojno učenje osnove   Srednji
# 380   5084.0  23-02-2024      Odustao       Strojno učenje osnove   Početni
# 381   5037.0  2023-11-04      Aktivan            Excel za analizu   Srednji
# 382   5016.0  08/18/2024      Aktivan  Statistika za Data Science  Napredni
# 385   5049.0  09-08-2024      Završen               Uvod u Python   Početni
# 388   5092.0  09/18/2024      Aktivan               Uvod u Python   Srednji
# 415   5049.0  01-09-2024      Završen               Uvod u Python   Početni
# 432   5018.0  20-12-2022      Aktivan  Statistika za Data Science   Srednji
# 433   5086.0  11/25/2024      Aktivan           Data Storytelling   Početni
# 434   5100.0  2024-12-22      Aktivan             Cloud Computing   Srednji
# 461   5005.0  08-03-2022      Aktivan  Statistika za Data Science   Početni
# 462   5092.0  2024-11-27      Aktivan               Uvod u Python   Srednji
# 468   5094.0  05/02/2023      Završen            Excel za analizu   Početni
# 469   5083.0  2024-09-29      Aktivan             Cloud Computing  Napredni
# 492   5057.0  2023-11-25      Aktivan            Excel za analizu   Početni
# 495   5090.0  24-02-2022      Aktivan      Vizualizacija podataka   početni
# 496   5023.0  2024-04-21      Završen       Strojno učenje osnove   Srednji
# 535   5038.0  06-12-2022      Aktivan             Cloud Computing   Srednji
# 536   5048.0  18-07-2024      Aktivan             Cloud Computing   Srednji
#
#      Trajanje_Sati  Cijena_USD  starost  duplikati
# 14            40.8      165.02       73       True
# 18            40.1      108.08       62       True
# 35            40.1      108.08       62       True
# 36            40.1      108.08       62       True
# 102           47.7      117.50       22       True
# 123           25.1      100.09       65       True
# 216           30.4      193.78       68       True
# 223           31.5       63.93       29       True
# 319           43.9       21.50       20       True
# 331           42.2       44.88       55       True
# 367           30.4       23.00       32       True
# 372           35.6       88.24       22       True
# 380           22.1       84.25       37       True
# 381           30.4        0.00       37       True
# 382           21.9       31.93       37       True
# 385           29.3      126.87       73       True
# 388           23.0      153.46       52       True
# 415           29.3      126.87       53       True
# 432           39.5     2000.00       70       True
# 433           28.3      180.95       70       True
# 434           29.6       82.70       70       True
# 461           30.4        0.01       37       True
# 462           23.0      153.46       37       True
# 468           31.8      121.47       69       True
# 469           22.5       61.05       69       True
# 492           30.4      106.91       55       True
# 495           37.6       77.63       65       True
# 496           40.0       68.33       65       True
# 535           40.8      165.02       24       True
# 536           21.0      133.62       24       True

# %%
polaznici_upisi_tecajevi.sort_values(by = ['PolaznikID', 'TecajID', 'UpisID'])
# Out:
#      PolaznikID  Godina_Rodjenja  Regija Jezik_Platforme  UpisID  TecajID  \
# 120        1001             1988  Afrika      Spanjolski     526   5097.0
# 400        1003             1978  Afrika        Engleski     317   5055.0
# 500        1004             1964   Azija        Engleski     165   5051.0
# 258        1007             1970   Azija        Engleski      60   5036.0
# 257        1007             1970   Azija        Engleski     349   5036.0
# ..          ...              ...     ...             ...     ...      ...
# 467        1398             1998  Europa        Engleski     138   5001.0
# 466        1398             1998  Europa        Engleski     517   5057.0
# 67         1400             1993   Azija      Spanjolski     402   5013.0
# 66         1400             1993   Azija      Spanjolski     525   5035.0
# 65         1400             1993   Azija      Spanjolski     552   5051.0
#
#     Datum_Upisa Status_Upisa            Naziv_Tecaja    Razina  Trajanje_Sati  \
# 120  2022-05-03      Završen         Cloud Computing  BEGINNER          500.0
# 400  10/17/2022      Završen  Vizualizacija podataka   srednji           23.5
# 500  30-03-2022      Aktivan            Napredni SQL   Početni           43.9
# 258  05/09/2023      Aktivan           Uvod u Python   Srednji           26.8
# 257  26-10-2024      Završen           Uvod u Python   Srednji           26.8
# ..          ...          ...                     ...       ...            ...
# 467  2023-01-24      Završen  Vizualizacija podataka   Srednji           40.2
# 466  27-06-2023      Aktivan        Excel za analizu   Početni           30.4
# 67   09-05-2023      Aktivan       Data Storytelling   Srednji           46.0
# 66   2024-07-17      Aktivan            Napredni SQL  ADVANCED           26.0
# 65   2023-12-24      Odustao            Napredni SQL   Početni           43.9
#
#      Cijena_USD  starost  duplikati
# 120      183.58       37      False
# 400      139.21       47      False
# 500       21.50       61      False
# 258      108.08       55      False
# 257      108.08       55      False
# ..          ...      ...        ...
# 467      185.49       27      False
# 466      106.91       27      False
# 67       182.10       32      False
# 66        20.00       32      False
# 65        21.50       32      False
#
# [551 rows x 14 columns]

# %%
polaznici_upisi_tecajevi.loc[polaznici_upisi_tecajevi["PolaznikID"]==1116]
# Out:
#      PolaznikID  Godina_Rodjenja            Regija Jezik_Platforme  UpisID  \
# 215        1116             1957  Sjeverna Amerika      Spanjolski     185
# 216        1116             1957  Sjeverna Amerika      Spanjolski     185
#
#      TecajID Datum_Upisa Status_Upisa     Naziv_Tecaja   Razina  \
# 215   5085.0  01-05-2024      Aktivan  Cloud Computing  Početni
# 216   5085.0  01-05-2024      Aktivan  Cloud Computing  Početni
#
#      Trajanje_Sati  Cijena_USD  starost  duplikati
# 215           30.4      193.78       68      False
# 216           30.4      193.78       68       True

# %%
polaznici_upisi_tecajevi.loc[polaznici_upisi_tecajevi["PolaznikID"]==1207]
# Out:
#      PolaznikID  Godina_Rodjenja      Regija Jezik_Platforme  UpisID  TecajID  \
# 115        1207             2001  Australija        Njemacki     338   5038.0
# 116        1207             2001  Australija        Njemacki     178   5048.0
# 535        1207             2001  Australija        Njemacki     338   5038.0
# 536        1207             2001  Australija        Njemacki     178   5048.0
#
#     Datum_Upisa Status_Upisa     Naziv_Tecaja   Razina  Trajanje_Sati  \
# 115  06-12-2022      Aktivan  Cloud Computing  Srednji           40.8
# 116  18-07-2024      Aktivan  Cloud Computing  Srednji           21.0
# 535  06-12-2022      Aktivan  Cloud Computing  Srednji           40.8
# 536  18-07-2024      Aktivan  Cloud Computing  Srednji           21.0
#
#      Cijena_USD  starost  duplikati
# 115      165.02       24      False
# 116      133.62       24      False
# 535      165.02       24       True
# 536      133.62       24       True

# %%
# if polaznikid and upisid = onda, else
